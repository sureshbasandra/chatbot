# %%
import requests

AUTH_KEY = "a3b8d153-18af-4f29-ba3a-eda0759fa1b4"
ORG_ID = "d2084ccd-986b-4c42-a871-f65245365bbf"

def getNodeStatus():
    url = "https://status-ap.botcentralapi.com/service-monitoring-0.1/sysadmin/nodejs/instance/status/"

    payload = ""
    headers = {
        'Authorization': AUTH_KEY,
        'OrganizationId': ORG_ID,
        'Content-Type': "application/json",
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers)
    return response.json()

result = getNodeStatus()
result
# Out:
# {'statusList': [{'createTime': 1537403604898,
#    'updateTime': 0,
#    'authType': 'key',
#    'success': False,
#    'botName': 'Product Bot',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '20795919',
#    'lpAccountUser': 'product_bot',
#    'type': 'messaging',
#    'botId': '6397dbc8db07fd4573113ebd5ee03c0b25df6ea4',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 1551783391524,
#    'updateTime': 1551783391739,
#    'authType': 'key',
#    'success': True,
#    'botName': 'HSBC Disputes Form bot -  Development',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '61122091',
#    'lpAccountUser': 'DISPUTE_BOT',
#    'type': 'messaging',
#    'botId': 'baba6c9787ee5d43332af5a1be81bd78889b92bb',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Ulster N InApp Survey Bot ',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747031906},"lastUpdateTime":1561747031908}}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '56951002',
#    'lpAccountUser': 'SurveybotUlsterNorth',
#    'type': 'messaging',
#    'botId': '80b8f51cea45f39b9bac1728f2b2cd09e5f5fefa',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '56951002::SurveybotUlsterNorth::80b8f::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 57,
#     'memory': 81375232,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/56951002--SurveybotUlsterNorth--80b8f--messaging-out-57.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/56951002--SurveybotUlsterNorth--80b8f--messaging-error-57.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Ulster N InApp Survey Bot ',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747056450},"lastUpdateTime":1561747056452},"lastMessage":1561063749436}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561063752524}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '49343281',
#    'lpAccountUser': 'SurveybotUlsterNorth(Backup)',
#    'type': 'messaging',
#    'botId': '80b8f51cea45f39b9bac1728f2b2cd09e5f5fefa',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '49343281::SurveybotUlsterNorth(Backup)::80b8f::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 64,
#     'memory': 77373440,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/49343281--SurveybotUlsterNorth-Backup---80b8f--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/49343281--SurveybotUlsterNorth-Backup---80b8f--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Ulster N InApp Survey Bot ',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747050162},"lastUpdateTime":1561747050164},"lastMessage":1560956306463}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1560956309625}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '49343281',
#    'lpAccountUser': 'SurveybotUlsterNorth',
#    'type': 'messaging',
#    'botId': '80b8f51cea45f39b9bac1728f2b2cd09e5f5fefa',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '49343281::SurveybotUlsterNorth::80b8f::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 78,
#     'memory': 79962112,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/49343281--SurveybotUlsterNorth--80b8f--messaging-out-78.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/49343281--SurveybotUlsterNorth--80b8f--messaging-error-78.log',
#     'status': 'online'}},
#   {'createTime': 1561120590242,
#    'updateTime': 1561626651543,
#    'authType': 'key',
#    'success': True,
#    'botName': 'BT Routing Bot NEW',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '25303315',
#    'lpAccountUser': 'routingbottest',
#    'type': 'chat',
#    'botId': '54ac260cc2b746ba37933f8a7f55e260030e3628',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true'},
#    'lastManualOperation': 'DEPLOYED',
#    'manualOperationTs': 1561626652837,
#    'manualOperationPerformedById': 'eacf8d2d2a134841bd16439cec2946d4',
#    'manualOperationPerformedByName': 'Fiona Ryan',
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Reschedule Appointment OOH Greeter Bot WM',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747053193},"lastUpdateTime":1561747053195},"lastMessage":1561686839079}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561686838565}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '61939614',
#    'lpAccountUser': 'OOH Reschedule Appointment Greeter bot',
#    'type': 'messaging',
#    'botId': 'b4a4784cbf387bdafe3aace622ced695f90d80c3',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '61939614::OOH Reschedule Appointment Greeter bot::b4a47::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 229,
#     'memory': 81522688,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/61939614--OOH-Reschedule-Appointment-Greeter-bot--b4a47--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/61939614--OOH-Reschedule-Appointment-Greeter-bot--b4a47--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 1556104112817,
#    'updateTime': 1556104139840,
#    'authType': 'key',
#    'success': True,
#    'botName': 'Own Data Source Patrick Fieger TEST',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '79785939',
#    'lpAccountUser': 'CB_Bot2',
#    'type': 'messaging',
#    'botId': '00da60af392c7ee42eb9ec9eb80d189f8049989e',
#    'serverName': 'Prod_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true',
#     '': ''},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 1545987867087,
#    'updateTime': 1546961052668,
#    'authType': 'key',
#    'success': False,
#    'botName': 'CRMP-bot1',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '61178832',
#    'lpAccountUser': 'BotcentralAI',
#    'type': 'chat',
#    'botId': '2d262940eca61274e823e0e38cd2af2ec94cdf4c',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'externalWebhookUrl': 'http://webhook.site/d50aea25-4dc1-40f4-a762-528c0b299057'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Liam ',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"error"}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '62384460',
#    'lpAccountUser': 'Liam',
#    'type': 'chat',
#    'botId': '7376f04706d3fdce6d850d3603410fa84d216a8a',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '62384460::Liam::7376f::chat',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 7,
#     'memory': 80367616,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPAgentChatSDKBot/BotCentralChatAgent.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/62384460--Liam--7376f--chat-out-7.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/62384460--Liam--7376f--chat-error-7.log',
#     'status': 'online'}},
#   {'createTime': 1541590110257,
#    'updateTime': 1541590318593,
#    'authType': 'key',
#    'success': False,
#    'botName': 'UnityMedia Routing Bot Example',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '42694119',
#    'lpAccountUser': 'serviceninja',
#    'type': 'chat',
#    'botId': '34d52ad418d31d0169d65a3bce212b8af3483984',
#    'serverName': 'Prod_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'FAQ structured bot (Italian) - Eden',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747056834},"lastUpdateTime":1561747056872},"lastMessage":1561530193966}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561530197105}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45593426',
#    'lpAccountUser': 'IT FAQ Bot',
#    'type': 'messaging',
#    'botId': '6e9f768dd5a4aee03e4ca3f113ef688ec4e274d9',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '45593426::IT FAQ Bot::6e9f7::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 191,
#     'memory': 79544320,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45593426--IT-FAQ-Bot--6e9f7--messaging-out-191.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45593426--IT-FAQ-Bot--6e9f7--messaging-error-191.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Lead Gen Bot -KK',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747046442},"lastUpdateTime":1561747046479},"lastMessage":1561420784073}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561420787178}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45593426',
#    'lpAccountUser': 'kk_lead_gen',
#    'type': 'messaging',
#    'botId': '91048647aefb3999b0faf717f8884ef332f6b6f1',
#    'serverName': 'Dev_Node_Server_2',
#    'appName': '45593426::kk_lead_gen::91048::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 4,
#     'memory': 81666048,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45593426--kk-lead-gen--91048--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45593426--kk-lead-gen--91048--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'PROD: Plusnet Sales Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"pingInfo":{"error":"**** Agent login failed - {\\"message\\":\\"getaddrinfo ENOTFOUND undefined undefined:443\\",\\"errno\\":\\"ENOTFOUND\\",\\"code\\":\\"ENOTFOUND\\",\\"syscall\\":\\"getaddrinfo\\",\\"hostname\\":\\"undefined\\",\\"host\\":\\"undefined\\",\\"port\\":443} **** ","lastUpdateTime":1561746917117},"status":"error"}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '78585400',
#    'lpAccountUser': 'PlusnetSalesADSLBot2',
#    'type': 'chat',
#    'botId': '1a3c954c932f9450ee6530480cb18bcef294ba41',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '78585400::PlusnetSalesADSLBot2::1a3c9::chat',
#    'configurations': {},
#    'lastManualOperation': 'MANUALLY_STARTED',
#    'manualOperationTs': 1560942255523,
#    'manualOperationPerformedById': '5a52b7db5fc84b44a4f617356a1e53fc',
#    'manualOperationPerformedByName': 'Monitoring Operations',
#    'pm2Info': {'id': 263,
#     'memory': 93306880,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPAgentChatSDKBot/BotCentralChatAgent.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/78585400--PlusnetSalesADSLBot2--1a3c9--chat-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/78585400--PlusnetSalesADSLBot2--1a3c9--chat-error.log',
#     'status': 'online'}},
#   {'createTime': 1547661800252,
#    'updateTime': 1547668013118,
#    'authType': 'key',
#    'success': False,
#    'botName': 'PROD: Plusnet Sales Bot',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '78585400',
#    'lpAccountUser': 'PlusnetSalesADSLBot1',
#    'type': 'chat',
#    'botId': '1a3c954c932f9450ee6530480cb18bcef294ba41',
#    'serverName': 'Prod_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Care Concierge WM',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747058338},"lastUpdateTime":1561747058340},"lastMessage":1561746983771}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561746270089}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '61939614',
#    'lpAccountUser': 'vm_wm_care_greeter_bot',
#    'type': 'messaging',
#    'botId': 'a0f4d367718eb8434b7c8c6c0f8fa28030a9b488',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '61939614::vm_wm_care_greeter_bot::a0f4d::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 227,
#     'memory': 119750656,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/61939614--vm-wm-care-greeter-bot--a0f4d--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/61939614--vm-wm-care-greeter-bot--a0f4d--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 1561647794121,
#    'updateTime': 1561647795484,
#    'authType': 'key',
#    'success': True,
#    'botName': 'PN MOB Routing Bot NEW',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '78585400',
#    'lpAccountUser': 'BOTSales1',
#    'type': 'chat',
#    'botId': 'd141ac2e8cb0584e507c11ebfc54a4d6d8891e82',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true'},
#    'lastManualOperation': 'DEPLOYED',
#    'manualOperationTs': 1561647796854,
#    'manualOperationPerformedById': 'eacf8d2d2a134841bd16439cec2946d4',
#    'manualOperationPerformedByName': 'Fiona Ryan',
#    'pm2Info': {}},
#   {'createTime': 1561647843773,
#    'updateTime': 1561647844854,
#    'authType': 'key',
#    'success': True,
#    'botName': 'PN MOB Routing Bot NEW',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '78585400',
#    'lpAccountUser': 'BOTSales2',
#    'type': 'chat',
#    'botId': 'd141ac2e8cb0584e507c11ebfc54a4d6d8891e82',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true'},
#    'lastManualOperation': 'DEPLOYED',
#    'manualOperationTs': 1561647846282,
#    'manualOperationPerformedById': 'eacf8d2d2a134841bd16439cec2946d4',
#    'manualOperationPerformedByName': 'Fiona Ryan',
#    'pm2Info': {}},
#   {'createTime': 1561647889441,
#    'updateTime': 1561647890753,
#    'authType': 'key',
#    'success': True,
#    'botName': 'PN MOB Routing Bot NEW',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '78585400',
#    'lpAccountUser': 'BOTSales3',
#    'type': 'chat',
#    'botId': 'd141ac2e8cb0584e507c11ebfc54a4d6d8891e82',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true'},
#    'lastManualOperation': 'DEPLOYED',
#    'manualOperationTs': 1561647892233,
#    'manualOperationPerformedById': 'eacf8d2d2a134841bd16439cec2946d4',
#    'manualOperationPerformedByName': 'Fiona Ryan',
#    'pm2Info': {}},
#   {'createTime': 1556613734670,
#    'updateTime': 1556613823910,
#    'authType': 'key',
#    'success': True,
#    'botName': 'Toby2',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '20674039',
#    'lpAccountUser': 'test@liveperson.com',
#    'type': 'messaging',
#    'botId': '594bce1db45638e31d7faa2ed0dec0ab107b0253',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true',
#     '': ''},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 1551387060251,
#    'updateTime': 1551387060836,
#    'authType': 'key',
#    'success': True,
#    'botName': 'FloBot',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '62085844',
#    'lpAccountUser': 'FLSTestBot1',
#    'type': 'messaging',
#    'botId': '1d749a408cea8c5dafe99ac550b30b409beab22a',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 1534848952818,
#    'updateTime': 1534848953207,
#    'authType': 'key',
#    'success': False,
#    'botName': 'Dev Workshop Testing Routing Bot',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '28584422',
#    'lpAccountUser': 'TestRoutingBot',
#    'type': 'messaging',
#    'botId': '4f6e68dcaca78aae1af3ec20f46b3450a61e27b4',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Omer Routing Bot (05-08-2019 10:36)',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747016469},"lastUpdateTime":1561747016471},"lastMessage":1561364993817}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561364993842}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '8582348',
#    'lpAccountUser': 'routing_bot',
#    'type': 'messaging',
#    'botId': '5b368dbcf142d068fd4232a23d5946336e18e269',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '8582348::routing_bot::5b368::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 207,
#     'memory': 76136448,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/8582348--routing-bot--5b368--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/8582348--routing-bot--5b368--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'MyVM Login Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747072569},"lastUpdateTime":1561747072570}}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '28584422',
#    'lpAccountUser': 'MyVMBot',
#    'type': 'messaging',
#    'botId': 'f77e8dabb9f30e5c0605312bfe8f8025b667ad36',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '28584422::MyVMBot::f77e8::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 13,
#     'memory': 83267584,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/28584422--MyVMBot--f77e8--messaging-out-13.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/28584422--MyVMBot--f77e8--messaging-error-13.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'XLN',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","lastMessage":1559732676957,"pingInfo":{"clock":{"currentTime":1561747046886},"lastUpdateTime":1561747046922}}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45593426',
#    'lpAccountUser': 'CB - XLN Bot (Shelli)',
#    'type': 'messaging',
#    'botId': '8066b485b229f81f33a86e12a83541b5d71ef481',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '45593426::CB - XLN Bot (Shelli)::8066b::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 211,
#     'memory': 77488128,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45593426--CB---XLN-Bot--Shelli---8066b--messaging-out-211.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45593426--CB---XLN-Bot--Shelli---8066b--messaging-error-211.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'VM Lead Gen Bot (DEV)',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"agentStatus":{"info":{"link":{"@href":"https://lo.agentvep.liveperson.net/api/account/79614321/agentSession/614501498/info","@rel":"self"},"agentName":"Salesy Sally","displayName":"Salesy Sally","loginName":"salesbot","id":"1160300132","maxChats":"0","availability":{"chat":"Away","chatReasonId":"","voice":"Offline"},"skillsInfo":{"skillInfo":{"id":"1148046632","name":"Bot"}}}},"lastUpdateTime":1561747057226}}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '79614321',
#    'lpAccountUser': 'salesbot',
#    'type': 'chat',
#    'botId': '1f654f72aa7b705037ac33ea542659030444e290',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '79614321::salesbot::1f654::chat',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 36,
#     'memory': 69521408,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPAgentChatSDKBot/BotCentralChatAgent.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/79614321--salesbot--1f654--chat-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/79614321--salesbot--1f654--chat-error.log',
#     'status': 'online'}},
#   {'createTime': 1539358734166,
#    'updateTime': 1542925638058,
#    'authType': 'key',
#    'success': False,
#    'botName': 'VM Lead Gen Bot (DEV)',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '87152698',
#    'lpAccountUser': 'lead-gen-bot',
#    'type': 'chat',
#    'botId': '1f654f72aa7b705037ac33ea542659030444e290',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'v2 Live Chat Routing Bot (Production) ',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"agentStatus":{"info":{"link":{"@href":"https://lo.agentvep.liveperson.net/api/account/45956611/agentSession/789478922/info","@rel":"self"},"agentName":"TalkTalk","displayName":"Live Chat Routing Bot","loginName":"LCRB","acd":{"awayTimeOut":"20","autoAnswering":"true","autoAwayAfterTimeOut":"false"},"id":"1249163332","maxChats":"-1","availability":{"chat":"Online","chatReasonId":"","voice":"Offline"},"skillsInfo":{"skillInfo":{"id":"1249159932","name":"Live Chat Routing Bot"}}}},"lastUpdateTime":1561747039242},"lastMessage":1561747026317}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561746800928}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '45956611',
#    'lpAccountUser': 'LCRB',
#    'type': 'chat',
#    'botId': 'd1daa9e4a6de369a4cfea075f96449a35fe280a0',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '45956611::LCRB::d1daa::chat',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 215,
#     'memory': 120295424,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPAgentChatSDKBot/BotCentralChatAgent.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45956611--LCRB--d1daa--chat-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45956611--LCRB--d1daa--chat-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'v2 Live Chat Routing Bot (Production) ',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"agentStatus":{"info":{"link":{"@href":"https://lo.agentvep.liveperson.net/api/account/45956611/agentSession/789552841/info","@rel":"self"},"agentName":"TalkTalk","displayName":"Live Chat Routing Bot (2)","loginName":"LCRB2","acd":{"awayTimeOut":"20","autoAnswering":"true","autoAwayAfterTimeOut":"false"},"id":"1249163732","maxChats":"-1","availability":{"chat":"Online","chatReasonId":"","voice":"Offline"},"skillsInfo":{"skillInfo":{"id":"1249159932","name":"Live Chat Routing Bot"}}}},"lastUpdateTime":1561747051774},"lastMessage":1561746846844}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561746846778}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45956611',
#    'lpAccountUser': 'LCRB2',
#    'type': 'chat',
#    'botId': 'd1daa9e4a6de369a4cfea075f96449a35fe280a0',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '45956611::LCRB2::d1daa::chat',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 194,
#     'memory': 75190272,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPAgentChatSDKBot/BotCentralChatAgent.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45956611--LCRB2--d1daa--chat-out-194.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45956611--LCRB2--d1daa--chat-error-194.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Horizon error code bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747013885},"lastUpdateTime":1561747013887}}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '28584422',
#    'lpAccountUser': 'login',
#    'type': 'messaging',
#    'botId': '30318b6557443edfcfb21e0e0fd424a860ea690c',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '28584422::login::30318::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 8,
#     'memory': 79892480,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/28584422--login--30318--messaging-out-8.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/28584422--login--30318--messaging-error-8.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Deflection Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747050755},"lastUpdateTime":1561747050757},"lastMessage":1561743932427}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561740144942}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45956611',
#    'lpAccountUser': 'CSDeflect',
#    'type': 'messaging',
#    'botId': '73f450c30357f3feb15dd4ddbf768711b61dc506',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '45956611::CSDeflect::73f45::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 22,
#     'memory': 84041728,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45956611--CSDeflect--73f45--messaging-out-22.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45956611--CSDeflect--73f45--messaging-error-22.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Deflection Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747039982},"lastUpdateTime":1561747039984},"lastMessage":1561746728933}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561746250945}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '45956611',
#    'lpAccountUser': 'CSDeflect2',
#    'type': 'messaging',
#    'botId': '73f450c30357f3feb15dd4ddbf768711b61dc506',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '45956611::CSDeflect2::73f45::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 19,
#     'memory': 86638592,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45956611--CSDeflect2--73f45--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45956611--CSDeflect2--73f45--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 1539345266672,
#    'updateTime': 1542925673364,
#    'authType': 'key',
#    'success': False,
#    'botName': "Lee's Test Router Bot",
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '87152698',
#    'lpAccountUser': 'leebot',
#    'type': 'chat',
#    'botId': '7b47cabccaa51d3420679ea479a745c7321542ca',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'FAQ Bot - Sweaty Betty',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747062819},"lastUpdateTime":1561747062857},"lastMessage":1561630068654}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561630069321}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45593426',
#    'lpAccountUser': 'Bot - CB Test (Shelli)',
#    'type': 'messaging',
#    'botId': 'df8e5ae2df558154a6e0e672f3f8776bc2eec635',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '45593426::Bot - CB Test (Shelli)::df8e5::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 208,
#     'memory': 81342464,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45593426--Bot---CB-Test--Shelli---df8e5--messaging-out-208.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45593426--Bot---CB-Test--Shelli---df8e5--messaging-error-208.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': '[DEV] Three.ie Messaging routing',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"error"}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '18786932',
#    'lpAccountUser': 'bot-m-1',
#    'type': 'messaging',
#    'botId': 'd43fad2a37a91802511c360b7844478688f1b148',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '18786932::bot-m-1::d43fa::messaging',
#    'configurations': {},
#    'lastManualOperation': 'MANUALLY_STARTED',
#    'manualOperationTs': 1560942376107,
#    'manualOperationPerformedById': '5a52b7db5fc84b44a4f617356a1e53fc',
#    'manualOperationPerformedByName': 'Monitoring Operations',
#    'pm2Info': {'id': 264,
#     'memory': 78946304,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/18786932--bot-m-1--d43fa--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/18786932--bot-m-1--d43fa--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 1543228595052,
#    'updateTime': 1557291592593,
#    'authType': 'key',
#    'success': False,
#    'botName': '[DEV] Three.ie Messaging routing',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '18786932',
#    'lpAccountUser': 'bot-m-2',
#    'type': 'messaging',
#    'botId': 'd43fad2a37a91802511c360b7844478688f1b148',
#    'serverName': 'Prod_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'lastManualOperation': 'MANUALLY_STOPPED',
#    'manualOperationTs': 1560942294092,
#    'manualOperationPerformedById': '5a52b7db5fc84b44a4f617356a1e53fc',
#    'manualOperationPerformedByName': 'Monitoring Operations',
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': '[DEV] Three.ie Messaging routing',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747071702},"lastUpdateTime":1561747071705},"lastMessage":1560941114793}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1560941112775}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '54456028',
#    'lpAccountUser': 'MsgEnRoute2',
#    'type': 'messaging',
#    'botId': 'd43fad2a37a91802511c360b7844478688f1b148',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '54456028::MsgEnRoute2::d43fa::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 34,
#     'memory': 79794176,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/54456028--MsgEnRoute2--d43fa--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/54456028--MsgEnRoute2--d43fa--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': '[DEV] Three.ie Messaging routing',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747014236},"lastUpdateTime":1561747014238},"lastMessage":1561043941683}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561043939666}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '54456028',
#    'lpAccountUser': 'MsgEnRoute',
#    'type': 'messaging',
#    'botId': 'd43fad2a37a91802511c360b7844478688f1b148',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '54456028::MsgEnRoute::d43fa::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 49,
#     'memory': 80936960,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/54456028--MsgEnRoute--d43fa--messaging-out-49.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/54456028--MsgEnRoute--d43fa--messaging-error-49.log',
#     'status': 'online'}},
#   {'createTime': 1560423047950,
#    'updateTime': 1560424355324,
#    'authType': 'key',
#    'success': True,
#    'botName': 'NA TEST INVISIBLE ROUTING BOT',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '61939614',
#    'lpAccountUser': 'test_invisible_bot',
#    'type': 'messaging',
#    'botId': '74e895e20096931fcec5e1d724be4888e281cd88',
#    'serverName': 'Prod_Node_Server_2',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true',
#     '': ''},
#    'lastManualOperation': 'UNDEPLOYED',
#    'manualOperationTs': 1561033673668,
#    'manualOperationPerformedById': 'db606b0cacc947ce89cd3116a95a475f',
#    'manualOperationPerformedByName': 'Demetrie Wyatt',
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Bet8 Pre conversation survey (demo)',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747064030},"lastUpdateTime":1561747064068},"lastMessage":1560410786087}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45593426',
#    'lpAccountUser': 'es_pre_survey_bot',
#    'type': 'messaging',
#    'botId': '37c22b8da89c0d916834140d84548e2300961b2b',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '45593426::es_pre_survey_bot::37c22::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 194,
#     'memory': 79581184,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45593426--es-pre-survey-bot--37c22--messaging-out-194.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45593426--es-pre-survey-bot--37c22--messaging-error-194.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'VM UK Sales BOT v4',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747013757},"lastUpdateTime":1561747013758},"lastMessage":1561730054675}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561730055284}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '61939614',
#    'lpAccountUser': 'VM_Sales_ROUTE_BOT_1',
#    'type': 'messaging',
#    'botId': '90ac48360da8dc2912853e0681565fab9915a718',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '61939614::VM_Sales_ROUTE_BOT_1::90ac4::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 215,
#     'memory': 77369344,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/61939614--VM-Sales-ROUTE-BOT-1--90ac4--messaging-out-215.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/61939614--VM-Sales-ROUTE-BOT-1--90ac4--messaging-error-215.log',
#     'status': 'online'}},
#   {'createTime': 1549972409567,
#    'updateTime': 1549972757585,
#    'authType': 'key',
#    'success': False,
#    'botName': 'xNA Vicky',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '61939614',
#    'lpAccountUser': 'Nathan Bot',
#    'type': 'messaging',
#    'botId': '99d3501452d0d386e6404868bba39750ae2ef644',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'lastManualOperation': 'UNDEPLOYED',
#    'manualOperationTs': 1560929642024,
#    'manualOperationPerformedById': 'd7c8e647a5ff461fb8f2de6c92319ef3',
#    'manualOperationPerformedByName': 'Chris McGrath',
#    'pm2Info': {}},
#   {'createTime': 1530817152468,
#    'updateTime': 1530818169032,
#    'authType': 'key',
#    'success': False,
#    'botName': 'OOO (Dev)',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '28584422',
#    'lpAccountUser': 'BOT-1',
#    'type': 'messaging',
#    'botId': 'd0c18a16523b5df34aecbd3c3fccc0ea52bcbb5a',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 1536595891207,
#    'updateTime': 1536595891278,
#    'authType': 'key',
#    'success': False,
#    'botName': 'Generic Shopify Bot',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '88411362',
#    'lpAccountUser': 'Bot',
#    'type': 'messaging',
#    'botId': '23f3fb0f7d94259bf047ab921657f4984d1f4b00',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 1549645286039,
#    'updateTime': 0,
#    'authType': 'key',
#    'success': False,
#    'botName': 'To Bot or not to Bot',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '39716368',
#    'lpAccountUser': 'IntroBot',
#    'type': 'chat',
#    'botId': 'bdf530637968af4fc08be97d54344000e998cfe3',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 1525844028131,
#    'updateTime': 1525900318381,
#    'authType': 'key',
#    'success': False,
#    'botName': 'Chu Test bot (09-05-2018 05:27)',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '25348739',
#    'lpAccountUser': 'bot_user_2',
#    'type': 'messaging',
#    'botId': '4e55705d35dc7f529e8d62df2635b3d94656c09a',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Robin Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"agentStatus":{"error":{"time":"2019-06-28T14:37:45.575-04:00","message":"No such agent session ID. Session may have ended.","internalCode":12}},"lastUpdateTime":1561747065579}}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '61178832',
#    'lpAccountUser': 'Botty',
#    'type': 'chat',
#    'botId': 'cd81c8fc3e8ebff000fbb73bfd0eef1dbaec97eb',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '61178832::Botty::cd81c::chat',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 172,
#     'memory': 69660672,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPAgentChatSDKBot/BotCentralChatAgent.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/61178832--Botty--cd81c--chat-out-172.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/61178832--Botty--cd81c--chat-error-172.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Routing bot SMS',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747071521},"lastUpdateTime":1561747071524},"lastMessage":1561415349309}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561415347288}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '61939614',
#    'lpAccountUser': 'vm_messaging_routing_bot2',
#    'type': 'messaging',
#    'botId': '11182757f5ce452b841fd1ba484e4f04a27a1d7d',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '61939614::vm_messaging_routing_bot2::11182::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 143,
#     'memory': 81625088,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/61939614--vm-messaging-routing-bot2--11182--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/61939614--vm-messaging-routing-bot2--11182--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': '[PROD] Three.ie Messaging Routing',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747059677},"lastUpdateTime":1561747059679},"lastMessage":1561747030133}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561746622357}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '63701280',
#    'lpAccountUser': 'Messaging_bot2',
#    'type': 'messaging',
#    'botId': '879f5b765883db5067b535277f8ff3298c0109d4',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '63701280::Messaging_bot2::879f5::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 190,
#     'memory': 115154944,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/63701280--Messaging-bot2--879f5--messaging-out-190.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/63701280--Messaging-bot2--879f5--messaging-error-190.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': '[PROD] Three.ie Messaging Routing',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747048316},"lastUpdateTime":1561747048318},"lastMessage":1561746916490}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561746524181}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '63701280',
#    'lpAccountUser': 'Messaging_bot1',
#    'type': 'messaging',
#    'botId': '879f5b765883db5067b535277f8ff3298c0109d4',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '63701280::Messaging_bot1::879f5::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 208,
#     'memory': 95793152,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
# ...
#    'appName': '45956611::routingbot4sms::8ce06::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 218,
#     'memory': 125816832,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45956611--routingbot4sms--8ce06--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45956611--routingbot4sms--8ce06--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'test123',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"error","pingInfo":{"clock":{"currentTime":1552498008134},"lastUpdateTime":1552498008136},"lastMessage":1552393516328}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '91200013',
#    'lpAccountUser': 'kamilbot',
#    'type': 'messaging',
#    'botId': '51ec157882bf08d3d91b587fd7ac8184dcee9053',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '91200013::kamilbot::51ec1::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 139,
#     'memory': 80883712,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/91200013--kamilbot--51ec1--messaging-out-139.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/91200013--kamilbot--51ec1--messaging-error-139.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'CMcG Routing Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"error"}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '61939614',
#    'lpAccountUser': 'CMcGBot',
#    'type': 'messaging',
#    'botId': '0e9fbeadd10bb73741598d0e885de6087d6d218b',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '61939614::CMcGBot::0e9fb::messaging',
#    'configurations': {},
#    'lastManualOperation': 'MANUALLY_STARTED',
#    'manualOperationTs': 1560943582588,
#    'manualOperationPerformedById': '5a52b7db5fc84b44a4f617356a1e53fc',
#    'manualOperationPerformedByName': 'Monitoring Operations',
#    'pm2Info': {'id': 270,
#     'memory': 75968512,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/61939614--CMcGBot--0e9fb--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/61939614--CMcGBot--0e9fb--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'VM Meeting 20022019 - 1',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747050082},"lastUpdateTime":1561747050118},"lastMessage":1559780269137}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '60041084',
#    'lpAccountUser': 'Virgin-Media-Bot-2',
#    'type': 'messaging',
#    'botId': '55417ffb7e8208cb7e0b9b3cfe895c87a32e384a',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '60041084::Virgin-Media-Bot-2::55417::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 108,
#     'memory': 80527360,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/60041084--Virgin-Media-Bot-2--55417--messaging-out-108.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/60041084--Virgin-Media-Bot-2--55417--messaging-error-108.log',
#     'status': 'online'}},
#   {'createTime': 1531231396167,
#    'updateTime': 1534751136111,
#    'authType': 'key',
#    'success': False,
#    'botName': 'Routing Bot (09-07-2018 03:02)',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '18786932',
#    'lpAccountUser': 'bot',
#    'type': 'chat',
#    'botId': '59fa93c31ec835c5dfdcc394f85493b4b4f8055d',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'UU',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747066399},"lastUpdateTime":1561747066436},"lastMessage":1561634035219}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561634035790}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45593426',
#    'lpAccountUser': 'UU Bot (Shelli)',
#    'type': 'messaging',
#    'botId': '871f581b661551ba2c5ff4050d64bdf20bf52be9',
#    'serverName': 'Dev_Node_Server_2',
#    'appName': '45593426::UU Bot (Shelli)::871f5::messaging',
#    'configurations': {},
#    'lastManualOperation': 'MANUALLY_STARTED',
#    'manualOperationTs': 1561474332151,
#    'manualOperationPerformedById': '40f6c0e578ab4fa8bf6853436d07584f',
#    'manualOperationPerformedByName': 'Shelli Baum',
#    'pm2Info': {'id': 12,
#     'memory': 79822848,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45593426--UU-Bot--Shelli---871f5--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45593426--UU-Bot--Shelli---871f5--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'InsureandGo FAQ Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747065819},"lastUpdateTime":1561747065857},"lastMessage":1561011919290}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561011920123}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45593426',
#    'lpAccountUser': 'FAQbot-SS',
#    'type': 'messaging',
#    'botId': 'b9b66ac12aa874b1d9562428ead84ce55361b03c',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '45593426::FAQbot-SS::b9b66::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 181,
#     'memory': 77598720,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45593426--FAQbot-SS--b9b66--messaging-out-181.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45593426--FAQbot-SS--b9b66--messaging-error-181.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'RBS InApp Survey Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747072833},"lastUpdateTime":1561747072835}}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '56951002',
#    'lpAccountUser': 'SurveybotRBS',
#    'type': 'messaging',
#    'botId': 'dd374e4a1e04d766f0735c6fc1ab319737b45340',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '56951002::SurveybotRBS::dd374::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 53,
#     'memory': 79204352,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/56951002--SurveybotRBS--dd374--messaging-out-53.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/56951002--SurveybotRBS--dd374--messaging-error-53.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'RBS InApp Survey Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","lastMessage":1560781588460,"pingInfo":{"clock":{"currentTime":1561747040102},"lastUpdateTime":1561747040104}}',
#    'bcSocketStatus': '{"status":"connected"}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '49343281',
#    'lpAccountUser': 'SurveybotRBS(Backup)',
#    'type': 'messaging',
#    'botId': 'dd374e4a1e04d766f0735c6fc1ab319737b45340',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '49343281::SurveybotRBS(Backup)::dd374::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 87,
#     'memory': 102793216,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/49343281--SurveybotRBS-Backup---dd374--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/49343281--SurveybotRBS-Backup---dd374--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'RBS InApp Survey Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","lastMessage":1561050373431,"pingInfo":{"clock":{"currentTime":1561747048265},"lastUpdateTime":1561747048267}}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561050376524}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '49343281',
#    'lpAccountUser': 'SurveybotRBS',
#    'type': 'messaging',
#    'botId': 'dd374e4a1e04d766f0735c6fc1ab319737b45340',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '49343281::SurveybotRBS::dd374::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 72,
#     'memory': 104124416,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/49343281--SurveybotRBS--dd374--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/49343281--SurveybotRBS--dd374--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'IMI 2way SMS ',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","lastMessage":1561037494434,"pingInfo":{"clock":{"currentTime":1561747047199},"lastUpdateTime":1561747047200}}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561037494986}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '33884409',
#    'lpAccountUser': 'routingbot4sms',
#    'type': 'messaging',
#    'botId': '624792b9b72b0efb6f7ed7342165a8940dded406',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '33884409::routingbot4sms::62479::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 150,
#     'memory': 82055168,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/33884409--routingbot4sms--62479--messaging-out-150.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/33884409--routingbot4sms--62479--messaging-error-150.log',
#     'status': 'online'}},
#   {'createTime': 1549033256929,
#    'updateTime': 1549033257080,
#    'authType': 'key',
#    'success': False,
#    'botName': 'IMI 2way SMS ',
#    'statusCode': 0,
#    'nodeStatus': 'unknown',
#    'lpSocketStatus': 'unknown',
#    'bcSocketStatus': 'unknown',
#    'lpAccountId': '33884409',
#    'lpAccountUser': 'LCBot',
#    'type': 'chat',
#    'botId': '624792b9b72b0efb6f7ed7342165a8940dded406',
#    'serverName': 'Demo_Node_Server_1',
#    'configurations': {'lpUserRole': 'ASSIGNED_AGENT',
#     'enableAccessibility': 'true'},
#    'manualOperationTs': 0,
#    'pm2Info': {}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Healthinsurancecomparison Bot (DR)',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747023642},"lastUpdateTime":1561747023678},"lastMessage":1561426731735}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561426729649}',
#    'environment': 'demo',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45593426',
#    'lpAccountUser': 'dr_demo_bot',
#    'type': 'messaging',
#    'botId': 'b492f9342c623822cdfa93d0052dff53e975cf18',
#    'serverName': 'Demo_Node_Server_1',
#    'appName': '45593426::dr_demo_bot::b492f::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 204,
#     'memory': 81117184,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45593426--dr-demo-bot--b492f--messaging-out-204.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45593426--dr-demo-bot--b492f--messaging-error-204.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'v2 InApp Routing Bot (Production)',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","lastMessage":1561747027207,"pingInfo":{"clock":{"currentTime":1561747065903},"lastUpdateTime":1561747065905}}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561747026691}',
#    'environment': 'prod',
#    'haType': 'PRIMARY',
#    'lpAccountId': '45956611',
#    'lpAccountUser': 'zIRB',
#    'type': 'messaging',
#    'botId': '23ec4524b24fd0fed3e1a1028f922807a6750042',
#    'serverName': 'Prod_Node_Server_1',
#    'appName': '45956611::zIRB::23ec4::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 199,
#     'memory': 85958656,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45956611--zIRB--23ec4--messaging-out-199.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45956611--zIRB--23ec4--messaging-error-199.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'v2 InApp Routing Bot (Production)',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561747051355},"lastUpdateTime":1561747051357},"lastMessage":1561745837456}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561745836934}',
#    'environment': 'prod',
#    'haType': 'SECONDARY',
#    'lpAccountId': '45956611',
#    'lpAccountUser': 'routingbot4inapp',
#    'type': 'messaging',
#    'botId': '23ec4524b24fd0fed3e1a1028f922807a6750042',
#    'serverName': 'Prod_Node_Server_2',
#    'appName': '45956611::routingbot4inapp::23ec4::messaging',
#    'configurations': {},
#    'manualOperationTs': 0,
#    'pm2Info': {'id': 221,
#     'memory': 92028928,
#     'cpu': 0,
#     'pm_exec_path': '/opt/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/opt/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/home/ubuntu/.pm2/logs/45956611--routingbot4inapp--23ec4--messaging-out.log',
#     'pm_err_log_path': '/home/ubuntu/.pm2/logs/45956611--routingbot4inapp--23ec4--messaging-error.log',
#     'status': 'online'}}]}

# %%
import requests

def getOrgs():
    url = "https://platformservice-ap.botcentralapi.com/bot-platform-manager-0.1/organization"

    payload = ""
    headers = {
        'Authorization': AUTH_KEY,
        'OrganizationId': ORG_ID,
        'Content-Type': "application/json",
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers)

    return response.json()

result_getOrgs = getOrgs()
result_getOrgs
# Out:
# {'success': True,
#  'successResult': {'organziations': [{'id': '78939ca8-b565-4a19-8178-d2989ab5c827',
#     'name': 'royal bank of scotland',
#     'displayName': 'Royal Bank of Scotland',
#     'addressLine': '123 Main St.',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': 'WC2N 5DU',
#     'type': 'ADMIN',
#     'primaryContactName': 'John Beadle',
#     'primaryContactEmail': 'jbeadle@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Derek Dempsey',
#     'billingContactEmail': 'ddempsey@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2018-05-23 16:31:20',
#     'modificationTime': '2018-05-23 16:31:20'},
#    {'id': '5bd3de64-b10c-4d2b-b58f-64609dcb8040',
#     'name': 'edf energy training',
#     'displayName': 'EDF Energy Training',
#     'addressLine': 'Gadeon House ',
#     'addressLine2': 'Grenadier Road Exeter Business Park  ',
#     'city': 'Exeter ',
#     'state': 'Exeter',
#     'country': 'GB',
#     'postalCode': 'EX1 3UT',
#     'type': 'ADMIN',
#     'primaryContactName': 'Lee Jeffreys',
#     'primaryContactEmail': 'ljeffreys@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Nathan Rogers',
#     'billingContactEmail': 'nrogers@liveperson.com',
#     'billingContactPhone': '5551212',
#     'modificationTime': '2018-10-09 22:17:21'},
#    {'id': 'd30798da-d070-459e-8685-bdc8d4f08cb3',
#     'name': 'edf energy',
#     'displayName': 'EDF Energy',
#     'addressLine': '90 Whitfield St',
#     'addressLine2': 'Bloomsbury',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': 'W1T 4EZ',
#     'type': 'ADMIN',
#     'primaryContactName': 'Remy Vidal',
#     'primaryContactEmail': 'rvidal@liveperson.com',
#     'primaryContactPhone': '123456',
#     'billingContactName': 'Remy Vidal',
#     'billingContactEmail': 'rvidal@liveperson.com',
#     'billingContactPhone': '123456',
#     'creationTime': '2018-08-08 11:32:08',
#     'modificationTime': '2018-08-08 11:32:08'},
#    {'id': 'b4296f83-dc21-4ff3-8b8a-75da48f6a13f',
#     'name': 'orange',
#     'displayName': 'Orange',
#     'addressLine': 'London',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': '12345',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Anat Hertzman',
#     'billingContactEmail': 'anath@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2018-06-17 18:04:24',
#     'modificationTime': '2018-06-17 18:04:24'},
#    {'id': '37b8f2d5-a00a-403e-b178-dcaf5c3b01d3',
#     'name': 'training lp emea',
#     'displayName': 'Training LP EMEA',
#     'addressLine': '250 South Oak Way',
#     'addressLine2': 'Green Park',
#     'city': 'Reading',
#     'state': 'UK',
#     'country': 'GB',
#     'postalCode': 'RG2 6UG',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Jon Altschuler',
#     'billingContactEmail': 'jaltschuler@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2018-09-11 04:10:35',
#     'modificationTime': '2018-09-11 04:10:35'},
#    {'id': '3d93a795-822d-43e4-b757-35e3006e265a',
#     'name': 'lp data science',
#     'displayName': 'LP Data Science',
#     'addressLine': 'Seattle',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'US',
#     'postalCode': '111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Mathew Dunn',
#     'primaryContactEmail': 'mdunn@liveperson.com',
#     'primaryContactPhone': '111',
#     'billingContactName': 'Seattle',
#     'billingContactEmail': 'mdunn@liveperson.com',
#     'billingContactPhone': '111',
#     'creationTime': '2019-06-20 01:38:13',
#     'modificationTime': '2019-06-20 01:38:13'},
#    {'id': '3b8e11d5-dd78-4e3e-b40d-4def482bc074',
#     'name': 'virgin media uk',
#     'displayName': 'Virgin Media UK',
#     'addressLine': 'Griffin House',
#     'addressLine2': '161 Hammersmith Road',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': 'W6 8BS',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Robert Coverdale',
#     'billingContactEmail': 'rcoverdale@liveperson.com',
#     'billingContactPhone': '5551212',
#     'modificationTime': '2018-08-03 10:44:31'},
#    {'id': 'ae8b8bb6-7aa4-489a-9279-f76527365ce1',
#     'name': 'its',
#     'displayName': 'ITS',
#     'addressLine': 'GreenPark',
#     'addressLine2': 'LivePerson',
#     'city': 'Reading',
#     'state': 'Israel',
#     'country': 'IL',
#     'postalCode': 'RG26UG',
#     'type': 'ADMIN',
#     'primaryContactName': 'John Beadle',
#     'primaryContactEmail': 'jbeadle@liveperson.com',
#     'primaryContactPhone': '07585436992',
#     'billingContactName': 'Avishai Abutbul',
#     'billingContactEmail': 'avishaia@liveperson.com',
#     'billingContactPhone': '7585436992',
#     'creationTime': '2019-06-06 18:15:10',
#     'modificationTime': '2019-06-06 18:15:10'},
#    {'id': '2c7d7762-6fa2-4a71-a8cd-9d51afe82444',
#     'name': 'cx engage',
#     'displayName': 'CX Engage',
#     'addressLine': '123 Main St.',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': '10111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ebrahim Dinat',
#     'primaryContactEmail': 'ebrahim@cxengage.co.za',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Lauren Hale',
#     'billingContactEmail': 'lhale@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2019-04-01 13:36:16',
#     'modificationTime': '2019-04-01 13:36:16'},
#    {'id': '94c48f0a-e8fd-46ab-84b8-1c2ac18fcecb',
#     'name': 'shahin ghazala',
#     'displayName': 'Shahin Ghazala',
#     'addressLine': '485 N Whisman Road',
#     'addressLine2': 'USA',
#     'city': 'Mountain View',
#     'state': '47656',
#     'country': 'AS',
#     'postalCode': '95014',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ravikiran Chittari',
#     'primaryContactEmail': 'jon@botcentral.ai',
#     'primaryContactPhone': '4083002525',
#     'billingContactName': 'Ghazala',
#     'billingContactEmail': 'jon@botcentral.ai',
#     'billingContactPhone': '4083002525',
#     'modificationTime': '2019-06-20 01:34:35'},
#    {'id': '5361a845-a899-480b-aa6c-017eb812b337',
#     'name': 'demos',
#     'displayName': 'Demos',
#     'addressLine': '11708 Olive Spring Ct',
#     'city': 'Cupertino',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': '95014',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ravikiran Chittari',
#     'primaryContactEmail': 'ravichittari@gmail.com',
#     'primaryContactPhone': '14083002525',
#     'billingContactName': 'Ravikiran',
#     'billingContactEmail': 'ravichittari@gmail.com',
#     'billingContactPhone': '14083002525',
#     'creationTime': '2019-03-01 15:14:12',
#     'modificationTime': '2019-03-01 15:14:12'},
#    {'id': '17777f88-ce20-46e7-ae8e-6233fdf5b4d2',
#     'name': 'cannes lions',
#     'displayName': 'Cannes Lions',
#     'addressLine': '123 Main St.',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': 'WC2N 5DU',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Chris Radanovic',
#     'billingContactEmail': 'cradanovic@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2018-05-23 17:19:34',
#     'modificationTime': '2018-05-23 17:19:34'},
#    {'id': 'b1681ce9-9c79-4328-823e-53f3b075b264',
#     'name': 'sky workshop',
#     'displayName': 'Sky Workshop',
#     'addressLine': '123',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'US',
#     'postalCode': '11111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Chris Radanovic',
#     'primaryContactEmail': 'cradanovic@liveperson.com',
#     'primaryContactPhone': '123456789',
#     'billingContactName': 'Chris',
#     'billingContactEmail': 'cradanovic@liveperson.com',
#     'billingContactPhone': '123456789',
#     'modificationTime': '2019-02-11 19:03:13'},
#    {'id': '8c9e66f8-33da-4bfb-a0b9-3d0a12b8c27f',
#     'name': 'talktalk cb workshop',
#     'displayName': 'TalkTalk CB Workshop',
#     'addressLine': '475 10th Ave',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': '10111',
#     'website': 'https://www.talktalk.co.uk/',
#     'type': 'ADMIN',
#     'primaryContactName': 'Stuart Holt',
#     'primaryContactEmail': 'stuart.holt@talktalkplc.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Colin Iliffe',
#     'billingContactEmail': 'colin.iliffe@talktalkplc.com',
#     'billingContactPhone': '5551212',
#     'modificationTime': '2019-01-03 20:31:37'},
#    {'id': '343afd3e-5d31-44d3-8b93-c0d22f4d6da5',
#     'name': 'lp consumer',
#     'displayName': 'LP Consumer',
#     'addressLine': '475 10th Ave',
#     'city': 'Tel Aviv',
#     'state': 'Tel Aviv',
#     'country': 'IL',
#     'postalCode': '10111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Liran Shpitalnik',
#     'billingContactEmail': 'liransh@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2019-02-11 04:09:34',
#     'modificationTime': '2019-02-11 04:09:34'},
#    {'id': '006ba517-fbcd-4126-80ae-d92423b5251a',
#     'name': 'orange france',
#     'displayName': 'Orange France',
#     'addressLine': '475 10th Ave',
#     'city': 'Paris',
#     'state': 'Paris',
#     'country': 'FR',
#     'postalCode': '10111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Omer Maroof',
#     'primaryContactEmail': 'omaroof@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Tom Durbin',
#     'billingContactEmail': 'tdurbin@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2019-01-31 16:23:52',
#     'modificationTime': '2019-01-31 16:23:52'},
#    {'id': '36c0ea0a-48c0-4192-924b-dc44b0334fdc',
#     'name': 'unitymedia',
#     'displayName': 'Unitymedia',
#     'addressLine': 'Aachener Straße 746-750',
#     'city': 'Cologne',
#     'state': 'n/a',
#     'country': 'DE',
#     'postalCode': '50933',
#     'type': 'ADMIN',
#     'primaryContactName': 'Remy Vidal',
#     'primaryContactEmail': 'rvidal@liveperson.com',
#     'primaryContactPhone': '123456',
#     'billingContactName': 'Remy Vidal',
#     'billingContactEmail': 'rvidal@liveperson.com',
#     'billingContactPhone': '123456',
#     'creationTime': '2018-07-27 15:54:10',
#     'modificationTime': '2018-07-27 15:54:10'},
#    {'id': '4bae9857-2c51-44a7-934c-eb4d62f25ecf',
#     'name': 'three ireland',
#     'displayName': 'Three Ireland',
#     'addressLine': 'Dublin',
#     'city': 'Dublin',
#     'state': 'Ireland',
#     'country': 'IE',
#     'type': 'ADMIN',
#     'primaryContactName': 'Amir Malenky',
#     'primaryContactEmail': 'amirm@liveperson.com',
#     'primaryContactPhone': '1234567890',
#     'billingContactName': 'Remy Vidal',
#     'billingContactEmail': 'rvidal@liveperson.com',
#     'billingContactPhone': '1234567890',
#     'creationTime': '2018-07-09 14:20:03',
#     'modificationTime': '2018-07-09 14:20:03'},
#    {'id': '2e799463-c82c-406c-b6c4-03dbb53219eb',
#     'name': 'training vmi oct 2018',
#     'displayName': 'Training VMI Oct 2018',
#     'addressLine': '1234 Limerick Street',
#     'city': 'Limerick',
#     'state': 'Dublin',
#     'country': 'IE',
#     'postalCode': '12345',
#     'type': 'ADMIN',
#     'primaryContactName': 'Lee Jeffries',
#     'primaryContactEmail': 'ljeffries@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Mark Lister',
#     'billingContactEmail': 'mlister@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2018-10-08 19:45:33',
#     'modificationTime': '2018-10-08 19:45:33'},
#    {'id': '83e314e7-f3ad-4cc0-84e9-cf3f31a97c5a',
#     'name': 'websia',
#     'displayName': 'WebSia',
#     'addressLine': 'Rua Cotoxó 1093',
#     'city': 'São Paulo',
#     'state': 'Perdizes',
#     'country': 'BR',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Leonardo Fernandes',
#     'billingContactEmail': 'leonardo@websia.com.br',
#     'billingContactPhone': '5551212',
#     'creationTime': '2018-10-29 20:36:01',
#     'modificationTime': '2018-10-29 20:36:01'},
#    {'id': 'e3b52d39-da5c-40a8-a340-00337e054fe3',
#     'name': 'smarkio',
#     'displayName': 'SMARKIO',
#     'addressLine': '1 Main St..',
#     'city': 'Brasilia',
#     'state': 'Brasilia',
#     'country': 'BR',
#     'postalCode': '10111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Chris Kong',
#     'billingContactEmail': 'ckong@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2019-03-01 22:13:45',
#     'modificationTime': '2019-03-01 22:13:45'},
#    {'id': '97405123-49bf-4b92-8674-c1e6cc49327f',
#     'name': 'lp institute',
#     'displayName': 'LP Institute',
#     'addressLine': '475 10th Ave',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': '10111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Deborah Corriol',
#     'primaryContactEmail': 'dcorriol@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Rolph Danko',
#     'billingContactEmail': 'rdanko@liveperson.com',
#     'billingContactPhone': '5551212',
#     'modificationTime': '2019-03-07 17:34:31'},
#    {'id': 'c553659f-8d27-448e-b2bf-40444cc682f7',
#     'name': 'crmpartners',
#     'displayName': 'CRMPartners',
#     'addressLine': 'Baron van Naellstraat 136m',
#     'city': 'Barneueld',
#     'state': 'Barneueld',
#     'country': 'NL',
#     'postalCode': '3771 LL Barneueld',
#     'website': 'http://www.crmpartners.nl',
#     'type': 'ADMIN',
#     'primaryContactName': 'Paul Molensky',
#     'primaryContactEmail': 'Paul.Molensky@crmpartners.com',
#     'primaryContactPhone': '+31 33 7999 845',
#     'billingContactName': 'Paul Molensky',
#     'billingContactEmail': 'Paul.Molensky@crmpartners.com',
#     'billingContactPhone': '+31 33 7999 845',
#     'creationTime': '2018-12-27 17:23:06',
#     'modificationTime': '2018-12-27 17:23:06'},
#    {'id': '488c10a5-a440-42f4-9d3e-989be43ec631',
#     'name': 'build a bot playground emea',
#     'displayName': 'Build a Bot Playground EMEA',
#     'addressLine': '1 Main St',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': '10111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Andrew Martin',
#     'billingContactEmail': 'amartin@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2019-03-01 18:50:09',
#     'modificationTime': '2019-03-01 18:50:09'},
#    {'id': '12c4cb2c-d1a8-46ae-beb5-541c85b1ae45',
#     'name': 'talktalk',
#     'displayName': 'TalkTalk',
#     'addressLine': '11 Evesham St',
#     'city': 'London',
#     'state': 'tbd',
#     'country': 'GB',
#     'postalCode': 'W11 4AR',
#     'website': 'https://www.talktalk.co.uk/',
#     'type': 'ADMIN',
#     'primaryContactName': 'Remy Vidal',
#     'primaryContactEmail': 'rvidal@liveperson.com',
#     'primaryContactPhone': 'tbd`',
#     'billingContactName': 'Mark Lister',
#     'billingContactEmail': 'mlister@liveperson.com',
#     'billingContactPhone': 'tbd',
#     'modificationTime': '2018-07-26 14:39:49'},
#    {'id': 'ed2502ac-2abb-4d56-a0dd-08064213eac0',
#     'name': 'liveperson support',
#     'displayName': 'LivePerson Support',
#     'addressLine': '11720 Amber Park Dr, ',
#     'addressLine2': 'Suite 400',
#     'city': 'Alpharetta',
#     'state': 'GA',
#     'country': 'US',
#     'postalCode': '30009',
#     'type': 'ADMIN',
#     'primaryContactName': 'Christian Krautwald',
#     'primaryContactEmail': 'ckrautwald@gmail.com',
#     'primaryContactPhone': '6786974454',
#     'billingContactName': 'Christian Krautwald',
#     'billingContactEmail': 'ckrautwald@liveperson.com',
#     'billingContactPhone': '6786974454',
#     'creationTime': '2019-05-22 18:56:16',
#     'modificationTime': '2019-05-22 18:56:16'},
#    {'id': 'ffe5a91e-b418-4d24-aa78-a429a3108ea7',
#     'name': 'vky intelligent automation',
#     'displayName': 'VKY Intelligent Automation',
#     'addressLine': "The Ca'D'Oro, 45 Gordon Street",
#     'city': 'Glasgow',
#     'state': 'Scotland',
#     'country': 'GB',
#     'postalCode': 'G1 3PE',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Joseph Forster',
#     'billingContactEmail': 'jforster@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2019-03-19 18:45:22',
#     'modificationTime': '2019-03-19 18:45:22'},
#    {'id': '4decac26-fbe8-47fc-bf4f-a81c0b15a416',
#     'name': 'liveperson emea',
#     'displayName': 'Liveperson EMEA',
#     'addressLine': '123 London Ave',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': 'WC2N 5DU',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Chris Radanovic',
#     'billingContactEmail': 'cradanovic@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2018-05-25 16:54:50',
#     'modificationTime': '2018-05-25 16:54:50'},
#    {'id': '6a612567-5283-44f8-8cc8-12d474b43d47',
#     'name': 'virgin media business',
#     'displayName': 'Virgin Media Business',
#     'addressLine': 'Media House, Bartley Wood Business Park',
#     'city': 'Hook',
#     'state': 'UK',
#     'country': 'GB',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jamil Arshad',
#     'primaryContactEmail': 'jamil.arshad@virginmedia.co.uk',
#     'primaryContactPhone': '01211231234',
#     'billingContactName': 'Jamil Arshad',
#     'billingContactEmail': 'jamil.arshad@virginmedia.co.uk',
#     'billingContactPhone': '01211231234',
#     'creationTime': '2019-03-21 15:33:39',
#     'modificationTime': '2019-03-21 15:33:39'},
#    {'id': '313cec30-40b3-4a73-a393-f5ea5fc45bff',
#     'name': 'aibs',
#     'displayName': 'AIBS',
#     'addressLine': '123 Main St',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': '10111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Lee Jeffreys',
#     'primaryContactEmail': 'ljeffreys@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Joseph Forster',
#     'billingContactEmail': 'jforster@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2019-03-22 14:33:33',
#     'modificationTime': '2019-03-22 14:33:33'},
#    {'id': 'a734ce0e-4e1b-4e81-9be9-bae276e5b439',
#     'name': 'credz lob 2',
#     'displayName': 'CREDZ LOB 2',
#     'addressLine': '123 Main Street',
#     'city': 'Sao Paulo',
#     'state': 'Sao Paulo',
#     'country': 'BR',
#     'postalCode': '11111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Alex Rocha',
#     'primaryContactEmail': 'alex@smarkio.com.br',
#     'primaryContactPhone': '123456789',
#     'billingContactName': 'Fernando Wolff',
#     'billingContactEmail': 'fnw@smarkio.com.br',
#     'billingContactPhone': '123456789',
#     'creationTime': '2019-05-22 14:01:12',
#     'modificationTime': '2019-05-22 14:01:12'},
#    {'id': 'd2084ccd-986b-4c42-a871-f65245365bbf',
#     'name': 'botcentral',
#     'displayName': 'botcentral',
#     'addressLine': '465 Fairchild dr',
#     'city': 'Mountain View',
#     'state': 'CA',
#     'country': 'US',
#     'website': 'www.botcentral.ai',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ravikiran Chittari',
#     'primaryContactEmail': 'rchittari@liveperson.com',
#     'primaryContactPhone': '4083002525',
#     'billingContactName': 'Ravikiran Chittari',
#     'billingContactEmail': 'rchittari@liveperson.com',
#     'billingContactPhone': '4083002525',
#     'modificationTime': '2018-05-08 18:18:13'},
#    {'id': '4028c561-05ed-48c0-a974-1ac6792a45df',
#     'name': 'qa',
#     'displayName': 'QA',
#     'addressLine': '485 whisman rd',
#     'city': 'Mountain View',
#     'state': 'CA',
#     'country': 'US',
#     'postalCode': '94068',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ravikiran Chittari',
#     'primaryContactEmail': 'rchittari@liveperson.com',
#     'primaryContactPhone': '1234565678',
#     'billingContactName': 'Ravikiran Chittari',
#     'billingContactEmail': 'rchittari@liveperson.com',
#     'billingContactPhone': '1234565678',
#     'creationTime': '2019-02-05 00:27:15',
#     'modificationTime': '2019-02-05 00:27:15'},
#    {'id': '9f440940-41cb-4286-ba8c-d12a14ada756',
#     'name': 'virgin media - ireland',
#     'displayName': 'Virgin Media - Ireland',
#     'addressLine': '123 No Street',
#     'city': 'Dublin',
#     'state': 'unknown',
#     'country': 'IE',
#     'type': 'ADMIN',
#     'primaryContactName': 'Nick Fifer',
#     'primaryContactEmail': 'nfifer@liveperson.com',
#     'primaryContactPhone': '1234567890',
#     'billingContactName': 'Mark Lister',
#     'billingContactEmail': 'mlister@liveperson.com',
#     'billingContactPhone': '1234567890',
#     'creationTime': '2018-07-03 16:47:47',
#     'modificationTime': '2018-07-03 16:47:47'},
#    {'id': '2ef62047-d9c4-417f-bf09-0012681a7dac',
#     'name': 'master of code',
#     'displayName': 'Master of Code',
#     'addressLine': ' 541 Jefferson Ave',
#     'city': 'Redwood City',
#     'state': 'CA',
#     'country': 'US',
#     'postalCode': '94063',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Glib Dobzhanksy',
#     'billingContactEmail': 'glib.dobzhanskyi@masterofcode.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2018-08-13 13:25:41',
#     'modificationTime': '2018-08-13 13:25:41'},
#    {'id': '6fedd692-bceb-4072-8e30-f3b6c7d47418',
#     'name': 'ee limited',
#     'displayName': 'EE Limited',
#     'addressLine': 'Hatfield Business Park',
#     'city': 'Hertfordshire',
#     'state': 'UK',
#     'country': 'GB',
#     'postalCode': 'AL10 9BMW',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ian Gulliford',
#     'primaryContactEmail': 'ian.gulliford@ee.co.uk',
#     'primaryContactPhone': '07538 106487',
#     'billingContactName': 'Ian Gulliford',
#     'billingContactEmail': 'ian.gulliford@ee.co.uk',
#     'billingContactPhone': '07538 106487',
#     'creationTime': '2019-02-21 15:45:21',
#     'modificationTime': '2019-02-21 15:45:21'},
#    {'id': '2bf192fa-8898-4d0d-b568-2c0101ba2d8b',
#     'name': 'training virginmedia ireland',
#     'displayName': 'Training VirginMedia Ireland',
#     'addressLine': "Croke Park Jones' Rd, Drumcondra",
#     'city': 'Dublin',
#     'state': 'Dublin',
#     'country': 'IE',
#     'type': 'ADMIN',
#     'primaryContactName': 'Jon Altschuler',
#     'primaryContactEmail': 'jaltschuler@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Chris Radanovic',
#     'billingContactEmail': 'cradanovic@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2018-08-19 20:27:13',
#     'modificationTime': '2018-08-19 20:27:13'},
#    {'id': '92cca3b4-07ae-4629-b372-400fd476f740',
#     'name': 'fireapitesting',
#     'displayName': 'FireApiTesting',
#     'addressLine': '981 Harness Ct',
#     'addressLine2': 'Apt# 16',
#     'city': 'San Ramon',
#     'state': 'CA',
#     'country': 'US',
#     'postalCode': '94583',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ravindranath Iruvuri',
#     'primaryContactEmail': 'riruvuri@liveperson.com',
#     'primaryContactPhone': '3434343434',
#     'billingContactName': 'Ravindranath Iruvuri',
#     'billingContactEmail': 'riruvuri@liveperson.com',
#     'billingContactPhone': '2396752862',
#     'creationTime': '2019-06-17 23:20:53',
#     'modificationTime': '2019-06-17 23:21:44',
#     'features': {'fireapiAccountEnabled': True,
#      'watsonEnabled': True,
#      'dialogflowEnabled': True}},
#    {'id': 'a29a3978-a4cb-4a2a-b2e3-e6af2319afcb',
#     'name': 'stratmetrix',
#     'displayName': 'StratMetrix',
#     'addressLine': '123 Main St.',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': '10111',
#     'type': 'ADMIN',
#     'primaryContactName': 'Lee Jeffreys',
#     'primaryContactEmail': 'ljeffreys@liveperson.com',
#     'primaryContactPhone': '5551212',
#     'billingContactName': 'Joseph Forster',
#     'billingContactEmail': 'jforster@liveperson.com',
#     'billingContactPhone': '5551212',
#     'creationTime': '2019-03-22 14:26:40',
#     'modificationTime': '2019-03-22 14:26:40'},
#    {'id': 'be1dab46-5a92-4986-b5ef-597571634bb0',
#     'name': 'hsbc (rbwm)',
#     'displayName': 'HSBC (RBWM)',
#     'addressLine': 'HSBC Private Bank (UK) Limited',
#     'addressLine2': '4th Floor City Point, 29 King Street',
#     'city': 'Leeds',
#     'state': 'Yorkshire',
#     'country': 'GB',
#     'postalCode': 'LS1 2HL',
#     'website': 'https://www.hsbc.co.uk/',
#     'type': 'ADMIN',
#     'primaryContactName': 'Cathryn Watts',
#     'primaryContactEmail': 'cathrynwatts@hsbc.com',
#     'primaryContactPhone': '+44 (0)114 2524406',
#     'billingContactName': 'Cathryn Watts',
#     'billingContactEmail': 'cathrynwatts@hsbc.com',
#     'billingContactPhone': '+44 (0)114 2524406',
#     'modificationTime': '2019-02-20 00:47:05'},
#    {'id': 'e2ea94cf-4d8e-41ea-a500-ed146b53e875',
#     'name': 'bt- british telecom',
#     'displayName': 'BT- British Telecom',
#     'addressLine': '81 Newgate St, London EC1A 7AJ',
#     'city': 'London',
#     'state': 'London',
#     'country': 'GB',
#     'postalCode': 'EC1A 7AJ',
#     'website': 'www.bt.com',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ali Yashab',
#     'primaryContactEmail': 'ayashab@liveperson.com',
#     'primaryContactPhone': '44 740 883 8893',
#     'billingContactName': 'Ali',
#     'billingContactEmail': 'ayashab@liveperson.com',
#     'billingContactPhone': '44 740 883 8893',
#     'creationTime': '2018-08-15 15:50:22',
#     'modificationTime': '2018-08-15 15:50:22'},
#    {'id': '639cc99f-dc4d-4112-8321-df25e313a6f7',
#     'name': 'plusnet',
#     'displayName': 'Plusnet',
#     'addressLine': '1 Any Street',
#     'city': 'London',
#     'state': 'United Kingdom',
#     'country': 'GB',
#     'postalCode': '17319',
#     'type': 'ADMIN',
#     'primaryContactName': 'Christian Garrido',
#     'primaryContactEmail': 'cgarrido@liveperson.com',
#     'primaryContactPhone': '1234567890',
#     'billingContactName': 'Chris Radanovic',
#     'billingContactEmail': 'cradanovic@liveperson.com',
#     'billingContactPhone': '7178416794',
#     'creationTime': '2018-06-27 18:52:40',
#     'modificationTime': '2018-06-27 18:52:40'}]}}

# %%
import requests

def getAllBotsInOrg(id):
    url = "https://platformservice-ap.botcentralapi.com/bot-platform-manager-0.1/chatbots"

    payload = ""
    headers = {
        'Authorization': AUTH_KEY,
        'OrganizationId': id,
        'Content-Type': "application/json",
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers)

    return response.json()

# %%
all_nodes = getNodeStatus()
orgs = getOrgs()

# %%
bots = getAllBotsInOrg('eaee7e0e-0f01-4e91-9e48-68fd1b07e378')
bots['successResult']['chatBotSummaryList']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-c91ab0ea6d6a> in <module>
#       1 bots = getAllBotsInOrg('eaee7e0e-0f01-4e91-9e48-68fd1b07e378')
# ----> 2 bots['successResult']['chatBotSummaryList']
#
# KeyError: 'chatBotSummaryList'

# %%
import copy
all_orgs = orgs['successResult']['organziations']

bots_with_org = []
for i, org in enumerate(all_orgs):
    try:
        print(i, org)
        bots = getAllBotsInOrg(org['id'])
        for bot in bots['successResult']['chatBotSummaryList']:
            bot['orgName'] = org.get('name', None)
            bot['orgId'] = org.get('id', None)
            bot['orgCountry'] = org.get('country', None)
            bots_with_org.append(copy.deepcopy(bot))
    except:
        continue
# Out:
# 0 {'id': '78939ca8-b565-4a19-8178-d2989ab5c827', 'name': 'royal bank of scotland', 'displayName': 'Royal Bank of Scotland', 'addressLine': '123 Main St.', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': 'WC2N 5DU', 'type': 'ADMIN', 'primaryContactName': 'John Beadle', 'primaryContactEmail': 'jbeadle@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Derek Dempsey', 'billingContactEmail': 'ddempsey@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2018-05-23 16:31:20', 'modificationTime': '2018-05-23 16:31:20'}
# 1 {'id': '5bd3de64-b10c-4d2b-b58f-64609dcb8040', 'name': 'edf energy training', 'displayName': 'EDF Energy Training', 'addressLine': 'Gadeon House ', 'addressLine2': 'Grenadier Road Exeter Business Park  ', 'city': 'Exeter ', 'state': 'Exeter', 'country': 'GB', 'postalCode': 'EX1 3UT', 'type': 'ADMIN', 'primaryContactName': 'Lee Jeffreys', 'primaryContactEmail': 'ljeffreys@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Nathan Rogers', 'billingContactEmail': 'nrogers@liveperson.com', 'billingContactPhone': '5551212', 'modificationTime': '2018-10-09 22:17:21'}
# 2 {'id': 'd30798da-d070-459e-8685-bdc8d4f08cb3', 'name': 'edf energy', 'displayName': 'EDF Energy', 'addressLine': '90 Whitfield St', 'addressLine2': 'Bloomsbury', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': 'W1T 4EZ', 'type': 'ADMIN', 'primaryContactName': 'Remy Vidal', 'primaryContactEmail': 'rvidal@liveperson.com', 'primaryContactPhone': '123456', 'billingContactName': 'Remy Vidal', 'billingContactEmail': 'rvidal@liveperson.com', 'billingContactPhone': '123456', 'creationTime': '2018-08-08 11:32:08', 'modificationTime': '2018-08-08 11:32:08'}
# 3 {'id': 'b4296f83-dc21-4ff3-8b8a-75da48f6a13f', 'name': 'orange', 'displayName': 'Orange', 'addressLine': 'London', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': '12345', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Anat Hertzman', 'billingContactEmail': 'anath@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2018-06-17 18:04:24', 'modificationTime': '2018-06-17 18:04:24'}
# 4 {'id': '37b8f2d5-a00a-403e-b178-dcaf5c3b01d3', 'name': 'training lp emea', 'displayName': 'Training LP EMEA', 'addressLine': '250 South Oak Way', 'addressLine2': 'Green Park', 'city': 'Reading', 'state': 'UK', 'country': 'GB', 'postalCode': 'RG2 6UG', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Jon Altschuler', 'billingContactEmail': 'jaltschuler@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2018-09-11 04:10:35', 'modificationTime': '2018-09-11 04:10:35'}
# 5 {'id': '3d93a795-822d-43e4-b757-35e3006e265a', 'name': 'lp data science', 'displayName': 'LP Data Science', 'addressLine': 'Seattle', 'city': 'Seattle', 'state': 'WA', 'country': 'US', 'postalCode': '111', 'type': 'ADMIN', 'primaryContactName': 'Mathew Dunn', 'primaryContactEmail': 'mdunn@liveperson.com', 'primaryContactPhone': '111', 'billingContactName': 'Seattle', 'billingContactEmail': 'mdunn@liveperson.com', 'billingContactPhone': '111', 'creationTime': '2019-06-20 01:38:13', 'modificationTime': '2019-06-20 01:38:13'}
# 6 {'id': '3b8e11d5-dd78-4e3e-b40d-4def482bc074', 'name': 'virgin media uk', 'displayName': 'Virgin Media UK', 'addressLine': 'Griffin House', 'addressLine2': '161 Hammersmith Road', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': 'W6 8BS', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Robert Coverdale', 'billingContactEmail': 'rcoverdale@liveperson.com', 'billingContactPhone': '5551212', 'modificationTime': '2018-08-03 10:44:31'}
# 7 {'id': 'ae8b8bb6-7aa4-489a-9279-f76527365ce1', 'name': 'its', 'displayName': 'ITS', 'addressLine': 'GreenPark', 'addressLine2': 'LivePerson', 'city': 'Reading', 'state': 'Israel', 'country': 'IL', 'postalCode': 'RG26UG', 'type': 'ADMIN', 'primaryContactName': 'John Beadle', 'primaryContactEmail': 'jbeadle@liveperson.com', 'primaryContactPhone': '07585436992', 'billingContactName': 'Avishai Abutbul', 'billingContactEmail': 'avishaia@liveperson.com', 'billingContactPhone': '7585436992', 'creationTime': '2019-06-06 18:15:10', 'modificationTime': '2019-06-06 18:15:10'}
# 8 {'id': '2c7d7762-6fa2-4a71-a8cd-9d51afe82444', 'name': 'cx engage', 'displayName': 'CX Engage', 'addressLine': '123 Main St.', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': '10111', 'type': 'ADMIN', 'primaryContactName': 'Ebrahim Dinat', 'primaryContactEmail': 'ebrahim@cxengage.co.za', 'primaryContactPhone': '5551212', 'billingContactName': 'Lauren Hale', 'billingContactEmail': 'lhale@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2019-04-01 13:36:16', 'modificationTime': '2019-04-01 13:36:16'}
# 9 {'id': '94c48f0a-e8fd-46ab-84b8-1c2ac18fcecb', 'name': 'shahin ghazala', 'displayName': 'Shahin Ghazala', 'addressLine': '485 N Whisman Road', 'addressLine2': 'USA', 'city': 'Mountain View', 'state': '47656', 'country': 'AS', 'postalCode': '95014', 'type': 'ADMIN', 'primaryContactName': 'Ravikiran Chittari', 'primaryContactEmail': 'jon@botcentral.ai', 'primaryContactPhone': '4083002525', 'billingContactName': 'Ghazala', 'billingContactEmail': 'jon@botcentral.ai', 'billingContactPhone': '4083002525', 'modificationTime': '2019-06-20 01:34:35'}
# 10 {'id': '5361a845-a899-480b-aa6c-017eb812b337', 'name': 'demos', 'displayName': 'Demos', 'addressLine': '11708 Olive Spring Ct', 'city': 'Cupertino', 'state': 'London', 'country': 'GB', 'postalCode': '95014', 'type': 'ADMIN', 'primaryContactName': 'Ravikiran Chittari', 'primaryContactEmail': 'ravichittari@gmail.com', 'primaryContactPhone': '14083002525', 'billingContactName': 'Ravikiran', 'billingContactEmail': 'ravichittari@gmail.com', 'billingContactPhone': '14083002525', 'creationTime': '2019-03-01 15:14:12', 'modificationTime': '2019-03-01 15:14:12'}
# 11 {'id': '17777f88-ce20-46e7-ae8e-6233fdf5b4d2', 'name': 'cannes lions', 'displayName': 'Cannes Lions', 'addressLine': '123 Main St.', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': 'WC2N 5DU', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Chris Radanovic', 'billingContactEmail': 'cradanovic@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2018-05-23 17:19:34', 'modificationTime': '2018-05-23 17:19:34'}
# 12 {'id': 'b1681ce9-9c79-4328-823e-53f3b075b264', 'name': 'sky workshop', 'displayName': 'Sky Workshop', 'addressLine': '123', 'city': 'New York', 'state': 'NY', 'country': 'US', 'postalCode': '11111', 'type': 'ADMIN', 'primaryContactName': 'Chris Radanovic', 'primaryContactEmail': 'cradanovic@liveperson.com', 'primaryContactPhone': '123456789', 'billingContactName': 'Chris', 'billingContactEmail': 'cradanovic@liveperson.com', 'billingContactPhone': '123456789', 'modificationTime': '2019-02-11 19:03:13'}
# 13 {'id': '8c9e66f8-33da-4bfb-a0b9-3d0a12b8c27f', 'name': 'talktalk cb workshop', 'displayName': 'TalkTalk CB Workshop', 'addressLine': '475 10th Ave', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': '10111', 'website': 'https://www.talktalk.co.uk/', 'type': 'ADMIN', 'primaryContactName': 'Stuart Holt', 'primaryContactEmail': 'stuart.holt@talktalkplc.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Colin Iliffe', 'billingContactEmail': 'colin.iliffe@talktalkplc.com', 'billingContactPhone': '5551212', 'modificationTime': '2019-01-03 20:31:37'}
# 14 {'id': '343afd3e-5d31-44d3-8b93-c0d22f4d6da5', 'name': 'lp consumer', 'displayName': 'LP Consumer', 'addressLine': '475 10th Ave', 'city': 'Tel Aviv', 'state': 'Tel Aviv', 'country': 'IL', 'postalCode': '10111', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Liran Shpitalnik', 'billingContactEmail': 'liransh@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2019-02-11 04:09:34', 'modificationTime': '2019-02-11 04:09:34'}
# 15 {'id': '006ba517-fbcd-4126-80ae-d92423b5251a', 'name': 'orange france', 'displayName': 'Orange France', 'addressLine': '475 10th Ave', 'city': 'Paris', 'state': 'Paris', 'country': 'FR', 'postalCode': '10111', 'type': 'ADMIN', 'primaryContactName': 'Omer Maroof', 'primaryContactEmail': 'omaroof@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Tom Durbin', 'billingContactEmail': 'tdurbin@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2019-01-31 16:23:52', 'modificationTime': '2019-01-31 16:23:52'}
# 16 {'id': '36c0ea0a-48c0-4192-924b-dc44b0334fdc', 'name': 'unitymedia', 'displayName': 'Unitymedia', 'addressLine': 'Aachener Straße 746-750', 'city': 'Cologne', 'state': 'n/a', 'country': 'DE', 'postalCode': '50933', 'type': 'ADMIN', 'primaryContactName': 'Remy Vidal', 'primaryContactEmail': 'rvidal@liveperson.com', 'primaryContactPhone': '123456', 'billingContactName': 'Remy Vidal', 'billingContactEmail': 'rvidal@liveperson.com', 'billingContactPhone': '123456', 'creationTime': '2018-07-27 15:54:10', 'modificationTime': '2018-07-27 15:54:10'}
# 17 {'id': '4bae9857-2c51-44a7-934c-eb4d62f25ecf', 'name': 'three ireland', 'displayName': 'Three Ireland', 'addressLine': 'Dublin', 'city': 'Dublin', 'state': 'Ireland', 'country': 'IE', 'type': 'ADMIN', 'primaryContactName': 'Amir Malenky', 'primaryContactEmail': 'amirm@liveperson.com', 'primaryContactPhone': '1234567890', 'billingContactName': 'Remy Vidal', 'billingContactEmail': 'rvidal@liveperson.com', 'billingContactPhone': '1234567890', 'creationTime': '2018-07-09 14:20:03', 'modificationTime': '2018-07-09 14:20:03'}
# 18 {'id': '2e799463-c82c-406c-b6c4-03dbb53219eb', 'name': 'training vmi oct 2018', 'displayName': 'Training VMI Oct 2018', 'addressLine': '1234 Limerick Street', 'city': 'Limerick', 'state': 'Dublin', 'country': 'IE', 'postalCode': '12345', 'type': 'ADMIN', 'primaryContactName': 'Lee Jeffries', 'primaryContactEmail': 'ljeffries@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Mark Lister', 'billingContactEmail': 'mlister@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2018-10-08 19:45:33', 'modificationTime': '2018-10-08 19:45:33'}
# 19 {'id': '83e314e7-f3ad-4cc0-84e9-cf3f31a97c5a', 'name': 'websia', 'displayName': 'WebSia', 'addressLine': 'Rua Cotoxó 1093', 'city': 'São Paulo', 'state': 'Perdizes', 'country': 'BR', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Leonardo Fernandes', 'billingContactEmail': 'leonardo@websia.com.br', 'billingContactPhone': '5551212', 'creationTime': '2018-10-29 20:36:01', 'modificationTime': '2018-10-29 20:36:01'}
# 20 {'id': 'e3b52d39-da5c-40a8-a340-00337e054fe3', 'name': 'smarkio', 'displayName': 'SMARKIO', 'addressLine': '1 Main St..', 'city': 'Brasilia', 'state': 'Brasilia', 'country': 'BR', 'postalCode': '10111', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Chris Kong', 'billingContactEmail': 'ckong@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2019-03-01 22:13:45', 'modificationTime': '2019-03-01 22:13:45'}
# 21 {'id': '97405123-49bf-4b92-8674-c1e6cc49327f', 'name': 'lp institute', 'displayName': 'LP Institute', 'addressLine': '475 10th Ave', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': '10111', 'type': 'ADMIN', 'primaryContactName': 'Deborah Corriol', 'primaryContactEmail': 'dcorriol@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Rolph Danko', 'billingContactEmail': 'rdanko@liveperson.com', 'billingContactPhone': '5551212', 'modificationTime': '2019-03-07 17:34:31'}
# 22 {'id': 'c553659f-8d27-448e-b2bf-40444cc682f7', 'name': 'crmpartners', 'displayName': 'CRMPartners', 'addressLine': 'Baron van Naellstraat 136m', 'city': 'Barneueld', 'state': 'Barneueld', 'country': 'NL', 'postalCode': '3771 LL Barneueld', 'website': 'http://www.crmpartners.nl', 'type': 'ADMIN', 'primaryContactName': 'Paul Molensky', 'primaryContactEmail': 'Paul.Molensky@crmpartners.com', 'primaryContactPhone': '+31 33 7999 845', 'billingContactName': 'Paul Molensky', 'billingContactEmail': 'Paul.Molensky@crmpartners.com', 'billingContactPhone': '+31 33 7999 845', 'creationTime': '2018-12-27 17:23:06', 'modificationTime': '2018-12-27 17:23:06'}
# 23 {'id': '488c10a5-a440-42f4-9d3e-989be43ec631', 'name': 'build a bot playground emea', 'displayName': 'Build a Bot Playground EMEA', 'addressLine': '1 Main St', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': '10111', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Andrew Martin', 'billingContactEmail': 'amartin@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2019-03-01 18:50:09', 'modificationTime': '2019-03-01 18:50:09'}
# 24 {'id': '12c4cb2c-d1a8-46ae-beb5-541c85b1ae45', 'name': 'talktalk', 'displayName': 'TalkTalk', 'addressLine': '11 Evesham St', 'city': 'London', 'state': 'tbd', 'country': 'GB', 'postalCode': 'W11 4AR', 'website': 'https://www.talktalk.co.uk/', 'type': 'ADMIN', 'primaryContactName': 'Remy Vidal', 'primaryContactEmail': 'rvidal@liveperson.com', 'primaryContactPhone': 'tbd`', 'billingContactName': 'Mark Lister', 'billingContactEmail': 'mlister@liveperson.com', 'billingContactPhone': 'tbd', 'modificationTime': '2018-07-26 14:39:49'}
# 25 {'id': 'ed2502ac-2abb-4d56-a0dd-08064213eac0', 'name': 'liveperson support', 'displayName': 'LivePerson Support', 'addressLine': '11720 Amber Park Dr, ', 'addressLine2': 'Suite 400', 'city': 'Alpharetta', 'state': 'GA', 'country': 'US', 'postalCode': '30009', 'type': 'ADMIN', 'primaryContactName': 'Christian Krautwald', 'primaryContactEmail': 'ckrautwald@gmail.com', 'primaryContactPhone': '6786974454', 'billingContactName': 'Christian Krautwald', 'billingContactEmail': 'ckrautwald@liveperson.com', 'billingContactPhone': '6786974454', 'creationTime': '2019-05-22 18:56:16', 'modificationTime': '2019-05-22 18:56:16'}
# 26 {'id': 'ffe5a91e-b418-4d24-aa78-a429a3108ea7', 'name': 'vky intelligent automation', 'displayName': 'VKY Intelligent Automation', 'addressLine': "The Ca'D'Oro, 45 Gordon Street", 'city': 'Glasgow', 'state': 'Scotland', 'country': 'GB', 'postalCode': 'G1 3PE', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Joseph Forster', 'billingContactEmail': 'jforster@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2019-03-19 18:45:22', 'modificationTime': '2019-03-19 18:45:22'}
# 27 {'id': '4decac26-fbe8-47fc-bf4f-a81c0b15a416', 'name': 'liveperson emea', 'displayName': 'Liveperson EMEA', 'addressLine': '123 London Ave', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': 'WC2N 5DU', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Chris Radanovic', 'billingContactEmail': 'cradanovic@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2018-05-25 16:54:50', 'modificationTime': '2018-05-25 16:54:50'}
# 28 {'id': '6a612567-5283-44f8-8cc8-12d474b43d47', 'name': 'virgin media business', 'displayName': 'Virgin Media Business', 'addressLine': 'Media House, Bartley Wood Business Park', 'city': 'Hook', 'state': 'UK', 'country': 'GB', 'type': 'ADMIN', 'primaryContactName': 'Jamil Arshad', 'primaryContactEmail': 'jamil.arshad@virginmedia.co.uk', 'primaryContactPhone': '01211231234', 'billingContactName': 'Jamil Arshad', 'billingContactEmail': 'jamil.arshad@virginmedia.co.uk', 'billingContactPhone': '01211231234', 'creationTime': '2019-03-21 15:33:39', 'modificationTime': '2019-03-21 15:33:39'}
# 29 {'id': '313cec30-40b3-4a73-a393-f5ea5fc45bff', 'name': 'aibs', 'displayName': 'AIBS', 'addressLine': '123 Main St', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': '10111', 'type': 'ADMIN', 'primaryContactName': 'Lee Jeffreys', 'primaryContactEmail': 'ljeffreys@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Joseph Forster', 'billingContactEmail': 'jforster@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2019-03-22 14:33:33', 'modificationTime': '2019-03-22 14:33:33'}
# 30 {'id': 'a734ce0e-4e1b-4e81-9be9-bae276e5b439', 'name': 'credz lob 2', 'displayName': 'CREDZ LOB 2', 'addressLine': '123 Main Street', 'city': 'Sao Paulo', 'state': 'Sao Paulo', 'country': 'BR', 'postalCode': '11111', 'type': 'ADMIN', 'primaryContactName': 'Alex Rocha', 'primaryContactEmail': 'alex@smarkio.com.br', 'primaryContactPhone': '123456789', 'billingContactName': 'Fernando Wolff', 'billingContactEmail': 'fnw@smarkio.com.br', 'billingContactPhone': '123456789', 'creationTime': '2019-05-22 14:01:12', 'modificationTime': '2019-05-22 14:01:12'}
# 31 {'id': 'd2084ccd-986b-4c42-a871-f65245365bbf', 'name': 'botcentral', 'displayName': 'botcentral', 'addressLine': '465 Fairchild dr', 'city': 'Mountain View', 'state': 'CA', 'country': 'US', 'website': 'www.botcentral.ai', 'type': 'ADMIN', 'primaryContactName': 'Ravikiran Chittari', 'primaryContactEmail': 'rchittari@liveperson.com', 'primaryContactPhone': '4083002525', 'billingContactName': 'Ravikiran Chittari', 'billingContactEmail': 'rchittari@liveperson.com', 'billingContactPhone': '4083002525', 'modificationTime': '2018-05-08 18:18:13'}
# 32 {'id': '4028c561-05ed-48c0-a974-1ac6792a45df', 'name': 'qa', 'displayName': 'QA', 'addressLine': '485 whisman rd', 'city': 'Mountain View', 'state': 'CA', 'country': 'US', 'postalCode': '94068', 'type': 'ADMIN', 'primaryContactName': 'Ravikiran Chittari', 'primaryContactEmail': 'rchittari@liveperson.com', 'primaryContactPhone': '1234565678', 'billingContactName': 'Ravikiran Chittari', 'billingContactEmail': 'rchittari@liveperson.com', 'billingContactPhone': '1234565678', 'creationTime': '2019-02-05 00:27:15', 'modificationTime': '2019-02-05 00:27:15'}
# 33 {'id': '9f440940-41cb-4286-ba8c-d12a14ada756', 'name': 'virgin media - ireland', 'displayName': 'Virgin Media - Ireland', 'addressLine': '123 No Street', 'city': 'Dublin', 'state': 'unknown', 'country': 'IE', 'type': 'ADMIN', 'primaryContactName': 'Nick Fifer', 'primaryContactEmail': 'nfifer@liveperson.com', 'primaryContactPhone': '1234567890', 'billingContactName': 'Mark Lister', 'billingContactEmail': 'mlister@liveperson.com', 'billingContactPhone': '1234567890', 'creationTime': '2018-07-03 16:47:47', 'modificationTime': '2018-07-03 16:47:47'}
# 34 {'id': '2ef62047-d9c4-417f-bf09-0012681a7dac', 'name': 'master of code', 'displayName': 'Master of Code', 'addressLine': ' 541 Jefferson Ave', 'city': 'Redwood City', 'state': 'CA', 'country': 'US', 'postalCode': '94063', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Glib Dobzhanksy', 'billingContactEmail': 'glib.dobzhanskyi@masterofcode.com', 'billingContactPhone': '5551212', 'creationTime': '2018-08-13 13:25:41', 'modificationTime': '2018-08-13 13:25:41'}
# 35 {'id': '6fedd692-bceb-4072-8e30-f3b6c7d47418', 'name': 'ee limited', 'displayName': 'EE Limited', 'addressLine': 'Hatfield Business Park', 'city': 'Hertfordshire', 'state': 'UK', 'country': 'GB', 'postalCode': 'AL10 9BMW', 'type': 'ADMIN', 'primaryContactName': 'Ian Gulliford', 'primaryContactEmail': 'ian.gulliford@ee.co.uk', 'primaryContactPhone': '07538 106487', 'billingContactName': 'Ian Gulliford', 'billingContactEmail': 'ian.gulliford@ee.co.uk', 'billingContactPhone': '07538 106487', 'creationTime': '2019-02-21 15:45:21', 'modificationTime': '2019-02-21 15:45:21'}
# 36 {'id': '2bf192fa-8898-4d0d-b568-2c0101ba2d8b', 'name': 'training virginmedia ireland', 'displayName': 'Training VirginMedia Ireland', 'addressLine': "Croke Park Jones' Rd, Drumcondra", 'city': 'Dublin', 'state': 'Dublin', 'country': 'IE', 'type': 'ADMIN', 'primaryContactName': 'Jon Altschuler', 'primaryContactEmail': 'jaltschuler@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Chris Radanovic', 'billingContactEmail': 'cradanovic@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2018-08-19 20:27:13', 'modificationTime': '2018-08-19 20:27:13'}
# 37 {'id': '92cca3b4-07ae-4629-b372-400fd476f740', 'name': 'fireapitesting', 'displayName': 'FireApiTesting', 'addressLine': '981 Harness Ct', 'addressLine2': 'Apt# 16', 'city': 'San Ramon', 'state': 'CA', 'country': 'US', 'postalCode': '94583', 'type': 'ADMIN', 'primaryContactName': 'Ravindranath Iruvuri', 'primaryContactEmail': 'riruvuri@liveperson.com', 'primaryContactPhone': '3434343434', 'billingContactName': 'Ravindranath Iruvuri', 'billingContactEmail': 'riruvuri@liveperson.com', 'billingContactPhone': '2396752862', 'creationTime': '2019-06-17 23:20:53', 'modificationTime': '2019-06-17 23:21:44', 'features': {'fireapiAccountEnabled': True, 'watsonEnabled': True, 'dialogflowEnabled': True}}
# 38 {'id': 'a29a3978-a4cb-4a2a-b2e3-e6af2319afcb', 'name': 'stratmetrix', 'displayName': 'StratMetrix', 'addressLine': '123 Main St.', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': '10111', 'type': 'ADMIN', 'primaryContactName': 'Lee Jeffreys', 'primaryContactEmail': 'ljeffreys@liveperson.com', 'primaryContactPhone': '5551212', 'billingContactName': 'Joseph Forster', 'billingContactEmail': 'jforster@liveperson.com', 'billingContactPhone': '5551212', 'creationTime': '2019-03-22 14:26:40', 'modificationTime': '2019-03-22 14:26:40'}
# 39 {'id': 'be1dab46-5a92-4986-b5ef-597571634bb0', 'name': 'hsbc (rbwm)', 'displayName': 'HSBC (RBWM)', 'addressLine': 'HSBC Private Bank (UK) Limited', 'addressLine2': '4th Floor City Point, 29 King Street', 'city': 'Leeds', 'state': 'Yorkshire', 'country': 'GB', 'postalCode': 'LS1 2HL', 'website': 'https://www.hsbc.co.uk/', 'type': 'ADMIN', 'primaryContactName': 'Cathryn Watts', 'primaryContactEmail': 'cathrynwatts@hsbc.com', 'primaryContactPhone': '+44 (0)114 2524406', 'billingContactName': 'Cathryn Watts', 'billingContactEmail': 'cathrynwatts@hsbc.com', 'billingContactPhone': '+44 (0)114 2524406', 'modificationTime': '2019-02-20 00:47:05'}
# 40 {'id': 'e2ea94cf-4d8e-41ea-a500-ed146b53e875', 'name': 'bt- british telecom', 'displayName': 'BT- British Telecom', 'addressLine': '81 Newgate St, London EC1A 7AJ', 'city': 'London', 'state': 'London', 'country': 'GB', 'postalCode': 'EC1A 7AJ', 'website': 'www.bt.com', 'type': 'ADMIN', 'primaryContactName': 'Ali Yashab', 'primaryContactEmail': 'ayashab@liveperson.com', 'primaryContactPhone': '44 740 883 8893', 'billingContactName': 'Ali', 'billingContactEmail': 'ayashab@liveperson.com', 'billingContactPhone': '44 740 883 8893', 'creationTime': '2018-08-15 15:50:22', 'modificationTime': '2018-08-15 15:50:22'}
# 41 {'id': '639cc99f-dc4d-4112-8321-df25e313a6f7', 'name': 'plusnet', 'displayName': 'Plusnet', 'addressLine': '1 Any Street', 'city': 'London', 'state': 'United Kingdom', 'country': 'GB', 'postalCode': '17319', 'type': 'ADMIN', 'primaryContactName': 'Christian Garrido', 'primaryContactEmail': 'cgarrido@liveperson.com', 'primaryContactPhone': '1234567890', 'billingContactName': 'Chris Radanovic', 'billingContactEmail': 'cradanovic@liveperson.com', 'billingContactPhone': '7178416794', 'creationTime': '2018-06-27 18:52:40', 'modificationTime': '2018-06-27 18:52:40'}

# %%
len(all_orgs)
# Out:
# 42

# %%
botIdOrgDictionary = {}
for item in bots_with_org:
    try:
        botIdOrgDictionary[item['chatBot']['id']] = item
    except Exception as e:
        print(e, item)
        continue

# %%
import pandas as pd

# %%
botIdDictionary = {}
for item in result['statusList']:
    botId = item['botId']
    if botId in botIdDictionary.keys():
        botIdDictionary[botId].append(item)
    else:
        botIdDictionary[botId] = [item]

# %%
botIdOrgDictionary['d7b1bedab9a31dcba60b2591302c38fb1ce68d2b'], botIdDictionary['d7b1bedab9a31dcba60b2591302c38fb1ce68d2b']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-399fed6dc51f> in <module>
# ----> 1 botIdOrgDictionary['d7b1bedab9a31dcba60b2591302c38fb1ce68d2b'], botIdDictionary['d7b1bedab9a31dcba60b2591302c38fb1ce68d2b']
#
# KeyError: 'd7b1bedab9a31dcba60b2591302c38fb1ce68d2b'

# %%
len(botIdDictionary.items()), len(botIdOrgDictionary.items())
# Out:
# (161, 667)

# %%
import json

statusInfoArr = []
for idx, (k, statusInfoList) in enumerate(botIdDictionary.items()):
    try:
        for statusInfo in statusInfoList:
            bot = botIdOrgDictionary.get(k, {})
            lpSocketStatus = json.loads(statusInfo['lpSocketStatus'])['status'] if statusInfo['lpSocketStatus'] and statusInfo['lpSocketStatus'] != 'unknown' else 'unknown'
            bcSocketStatus = json.loads(statusInfo['bcSocketStatus'])['status'] if statusInfo['bcSocketStatus'] and statusInfo['lpSocketStatus'] != 'unknown' else 'unknown'
            statusKeys = statusInfo.keys()
            status = [statusInfo.get('botId', None),
                      statusInfo.get('botName', None),
                      statusInfo.get('environment', None),
                      statusInfo.get('serverName', None),
                      statusInfo.get('lpAccountId', None),
                      statusInfo.get('lpAccountUser', None),
                      statusInfo.get('type', None),
                      bot.get('orgId', None),
                      bot.get('orgName', None),
                      bot.get('orgCountry', None),
                      bot.get('chatBot', {}).get('version', None),
                      bcSocketStatus,
                      statusInfo.get('nodeStatus', None),
                      lpSocketStatus]
            statusInfoArr.append(status)
    except Exception as e:
#         print(e)
        print(idx, k, bot['chatBot']['name'])
        continue

# %%
botIdDictionary['1929dd0634515575b03cba583d5e75d447d3a461'], botIdOrgDictionary['1929dd0634515575b03cba583d5e75d447d3a461']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-8205bb6ee2ea> in <module>
# ----> 1 botIdDictionary['1929dd0634515575b03cba583d5e75d447d3a461'], botIdOrgDictionary['1929dd0634515575b03cba583d5e75d447d3a461']
#
# KeyError: '1929dd0634515575b03cba583d5e75d447d3a461'

# %%
df = pd.DataFrame(statusInfoArr, columns = ['botId', 'botName',
                                            'environment','serverName','lpAccountId','lpAccountUser',
                                            'type','orgId','orgName','orgCountry','version', 'bcSocketStatus',
                                           'nodeStatus','lpSocketStatus'])

# %%
len(df)
# Out:
# 207

# %%
df.to_csv('~/notebooks/bot_results_aws_eu.csv', index=None)

# %%
# !open ./
