# %%
import requests

AUTH_KEY = "ed2da2c0-ee6a-411f-9984-1fac87db2485"
ORG_ID = "d2084ccd-986b-4c42-a871-f65245365bbf"

def getNodeStatus():
    url = "https://sy.bc-mgmt.liveperson.net/service-monitoring-0.1/sysadmin/nodejs/instance/status/"

    payload = ""
    headers = {
        'Authorization': AUTH_KEY,
        'OrganizationId': ORG_ID,
        'Content-Type': "application/json",
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers)
    return response.json()

result = getNodeStatus()
result
# Out:
# {'statusList': [{'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Retail Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","lastMessage":1561456196224,"pingInfo":{"agentStatus":{"info":{"link":{"@href":"https://sy.agentvep.liveperson.net/api/account/8894374/agentSession/929748825/info","@rel":"self"},"agentName":"Bot User","displayName":"Bot User","loginName":"bot_user","id":"953419170","maxChats":"-1","availability":{"chat":"Online","chatReasonId":"","voice":"Offline"},"skillsInfo":{"skillInfo":{"id":"953417270","name":"Bot"}}}},"lastUpdateTime":1561595969219}}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561455407294}',
#    'environment': 'demo',
#    'haType': 'SECONDARY',
#    'lpAccountId': '8894374',
#    'lpAccountUser': 'bot_user',
#    'type': 'chat',
#    'botId': 'cdd582d0ce7ffaaad824d65171abaf44ea4365d8',
#    'serverName': 'Demo_Node_Server_2',
#    'appName': '8894374::bot_user::cdd58::chat',
#    'configurations': {},
#    'pm2Info': {'id': 7,
#     'memory': 77303808,
#     'cpu': 0,
#     'pm_exec_path': '/liveperson/code/LivePersonNodeServer/LPAgentChatSDKBot/BotCentralChatAgent.js',
#     'pm_cwd': '/liveperson/code/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/root/.pm2/logs/8894374--bot-user--cdd58--chat-out.log',
#     'pm_err_log_path': '/root/.pm2/logs/8894374--bot-user--cdd58--chat-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'OCA Consumer Service Routing Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","lastMessage":1561529775759,"pingInfo":{"clock":{"currentTime":1561595956104},"lastUpdateTime":1561595956107}}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561529775238}',
#    'environment': 'demo',
#    'haType': 'SECONDARY',
#    'lpAccountId': '43249447',
#    'lpAccountUser': 'oca-service-routing-bot',
#    'type': 'messaging',
#    'botId': 'e5c36c16264a0cac9fc799b37d1a3b3cea9234cb',
#    'serverName': 'Demo_Node_Server_2',
#    'appName': '43249447::oca-service-routing-bot::e5c36::messaging',
#    'configurations': {},
#    'pm2Info': {'id': 4,
#     'memory': 92291072,
#     'cpu': 0,
#     'pm_exec_path': '/liveperson/code/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/liveperson/code/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/root/.pm2/logs/43249447--oca-service-routing-bot--e5c36--messaging-out.log',
#     'pm_err_log_path': '/root/.pm2/logs/43249447--oca-service-routing-bot--e5c36--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'OCA Business Service Routing Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561595955174},"lastUpdateTime":1561595955177},"lastMessage":1561436280878}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561436281584}',
#    'environment': 'demo',
#    'haType': 'SECONDARY',
#    'lpAccountId': '43249447',
#    'lpAccountUser': 'oca-business-service-routing-bot',
#    'type': 'messaging',
#    'botId': '2aeefd3573052a62ae62ccaff279db308da24ad8',
#    'serverName': 'Demo_Node_Server_2',
#    'appName': '43249447::oca-business-service-routing-bot::2aeef::messaging',
#    'configurations': {},
#    'pm2Info': {'id': 5,
#     'memory': 88416256,
#     'cpu': 0,
#     'pm_exec_path': '/liveperson/code/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/liveperson/code/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/root/.pm2/logs/43249447--oca-business-service-routing-bot--2aeef--messaging-out.log',
#     'pm_err_log_path': '/root/.pm2/logs/43249447--oca-business-service-routing-bot--2aeef--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'Parkin Routing Bot',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","lastMessage":1561534759119,"pingInfo":{"clock":{"currentTime":1561595954355},"lastUpdateTime":1561595954359}}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561534759915}',
#    'environment': 'demo',
#    'haType': 'SECONDARY',
#    'lpAccountId': '43249447',
#    'lpAccountUser': 'RoutingBot',
#    'type': 'messaging',
#    'botId': '9e8fa97d4802002dfacb2aa4074ecb609a1a3b7f',
#    'serverName': 'Demo_Node_Server_2',
#    'appName': '43249447::RoutingBot::9e8fa::messaging',
#    'configurations': {},
#    'pm2Info': {'id': 3,
#     'memory': 94834688,
#     'cpu': 0,
#     'pm_exec_path': '/liveperson/code/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/liveperson/code/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/root/.pm2/logs/43249447--RoutingBot--9e8fa--messaging-out.log',
#     'pm_err_log_path': '/root/.pm2/logs/43249447--RoutingBot--9e8fa--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'gc-agent-bot(echo-bot) (06-25-2019 06:26)',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561595932409},"lastUpdateTime":1561595932413},"lastMessage":1561590718885}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561590719633}',
#    'environment': 'demo',
#    'haType': 'SECONDARY',
#    'lpAccountId': '25644629',
#    'lpAccountUser': 'Agent-Bot',
#    'type': 'messaging',
#    'botId': '8e87e4b92bdd89078a5d52b82f4090cabf968a7b',
#    'serverName': 'Demo_Node_Server_2',
#    'appName': '25644629::Agent-Bot::8e87e::messaging',
#    'configurations': {},
#    'pm2Info': {'id': 9,
#     'memory': 79855616,
#     'cpu': 0,
#     'pm_exec_path': '/liveperson/code/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/liveperson/code/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/root/.pm2/logs/25644629--Agent-Bot--8e87e--messaging-out.log',
#     'pm_err_log_path': '/root/.pm2/logs/25644629--Agent-Bot--8e87e--messaging-error.log',
#     'status': 'online'}},
#   {'createTime': 0,
#    'updateTime': 0,
#    'authType': 'pwd',
#    'success': False,
#    'botName': 'gc-routing-bot ALFA (28707354) (05-24-2019 01:13) (06-25-2019 05:56)',
#    'statusCode': 0,
#    'nodeStatus': 'online',
#    'lpSocketStatus': '{"status":"connected","pingInfo":{"clock":{"currentTime":1561595946674},"lastUpdateTime":1561595946678},"lastMessage":1561590663849}',
#    'bcSocketStatus': '{"status":"connected","lastMessage":1561588150373}',
#    'environment': 'demo',
#    'haType': 'SECONDARY',
#    'lpAccountId': '25644629',
#    'lpAccountUser': 'ATRB-Routing-Bot',
#    'type': 'messaging',
#    'botId': 'e824b2c7026d1a7ee60378a9b19109b638134143',
#    'serverName': 'Demo_Node_Server_2',
#    'appName': '25644629::ATRB-Routing-Bot::e824b::messaging',
#    'configurations': {},
#    'pm2Info': {'id': 16,
#     'memory': 57417728,
#     'cpu': 0,
#     'pm_exec_path': '/liveperson/code/LivePersonNodeServer/LPMessengerSDKBot/src/BotCentralConnector.js',
#     'pm_cwd': '/liveperson/code/LivePersonNodeServer/DeploymentAPI',
#     'pm_out_log_path': '/root/.pm2/logs/25644629--ATRB-Routing-Bot--e824b--messaging-out.log',
#     'pm_err_log_path': '/root/.pm2/logs/25644629--ATRB-Routing-Bot--e824b--messaging-error.log',
#     'status': 'online'}}]}

# %%
import requests

def getOrgs():
    url = "https://sy.bc-platform.liveperson.net/bot-platform-manager-0.1/organization"

    payload = ""
    headers = {
        'Authorization': AUTH_KEY,
        'OrganizationId': ORG_ID,
        'Content-Type': "application/json",
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers)

    return response.json()

result_getOrgs = getOrgs()
result_getOrgs
# Out:
# {'success': True,
#  'successResult': {'organziations': [{'id': '1ee06326-727c-4b92-b2b2-31167a204e43',
#     'name': '19465488',
#     'displayName': '19465488',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 20:40:09',
#     'modificationTime': '2019-06-19 20:40:09',
#     'createdBy': 'LE_SSO'},
#    {'id': '102fb7c9-4bed-45a4-b595-258d592f6e43',
#     'name': '63627617',
#     'displayName': '63627617',
#     'addressLine': '485 N Whisman Rd',
#     'addressLine2': 'Office 100',
#     'city': 'Mountain View',
#     'state': 'CA',
#     'country': 'US',
#     'postalCode': '94043',
#     'type': 'ADMIN',
#     'primaryContactName': 'Sergey Kalashian',
#     'primaryContactEmail': 'sergeyk@liveperson.com',
#     'primaryContactPhone': '1234',
#     'billingContactName': 'Sergey Kalashian',
#     'billingContactEmail': 'sergeyk@liveperson.com',
#     'billingContactPhone': '1234',
#     'creationTime': '2019-06-05 13:34:02',
#     'modificationTime': '2019-06-05 13:34:02'},
#    {'id': '86b40dc5-d6cd-47ac-bd1a-e659cf91ef8a',
#     'name': '73948358',
#     'displayName': '73948358',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 17:21:44',
#     'modificationTime': '2019-06-19 17:21:44',
#     'createdBy': 'LE_SSO'},
#    {'id': '02771838-1adc-4466-b4c0-aa38542ecb23',
#     'name': '23197511',
#     'displayName': '23197511',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 14:23:25',
#     'modificationTime': '2019-06-19 14:23:25',
#     'createdBy': 'LE_SSO'},
#    {'id': 'faa0f639-5886-41db-8a0f-d95d14bb2ee4',
#     'name': '33350555',
#     'displayName': '33350555',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 18:47:31',
#     'modificationTime': '2019-06-19 18:47:31',
#     'createdBy': 'LE_SSO'},
#    {'id': 'c761f097-2c21-4742-ba09-04d1e2042ea3',
#     'name': '75330252',
#     'displayName': '75330252',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 21:42:53',
#     'modificationTime': '2019-06-19 21:42:53',
#     'createdBy': 'LE_SSO'},
#    {'id': '4239987c-af76-4314-a744-0d45167b68f2',
#     'name': '25644629',
#     'displayName': '25644629',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-25 13:45:39',
#     'modificationTime': '2019-06-25 13:45:39',
#     'createdBy': 'LE_SSO'},
#    {'id': '829c6c20-ae01-4b91-b1ed-58358f90f6b4',
#     'name': '63455983',
#     'displayName': '63455983',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 14:21:57',
#     'modificationTime': '2019-06-19 14:21:57',
#     'createdBy': 'LE_SSO'},
#    {'id': '103639cf-03fe-4650-a85f-0982b34f27ad',
#     'name': '43249447',
#     'displayName': '43249447',
#     'addressLine': '485 N Whisman Rd',
#     'addressLine2': 'Office 100',
#     'city': 'Mountain View',
#     'state': 'CA',
#     'country': 'US',
#     'postalCode': '94043',
#     'type': 'ADMIN',
#     'primaryContactName': 'Sergey Kalashian',
#     'primaryContactEmail': 'sergeyk@liveperson.com',
#     'primaryContactPhone': '1234',
#     'billingContactName': 'Sergey Kalashian',
#     'billingContactEmail': 'sergeyk@liveperson.com',
#     'billingContactPhone': '1234',
#     'creationTime': '2019-06-05 13:35:27',
#     'modificationTime': '2019-06-05 13:35:27'},
#    {'id': '54378c38-74dd-4786-a2a9-c053f3fbe38e',
#     'name': '27984200',
#     'displayName': '27984200',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 13:38:59',
#     'modificationTime': '2019-06-19 13:38:59',
#     'createdBy': 'LE_SSO'},
#    {'id': '7ccee28d-8634-413b-9ecb-d7b77c88f1ac',
#     'name': '5445139',
#     'displayName': '5445139',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-20 09:17:16',
#     'modificationTime': '2019-06-20 09:17:16',
#     'createdBy': 'LE_SSO'},
#    {'id': '37fbc083-cb3d-42ba-a901-217f6565ceb2',
#     'name': '82620305',
#     'displayName': '82620305',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 21:43:25',
#     'modificationTime': '2019-06-19 21:43:25',
#     'createdBy': 'LE_SSO'},
#    {'id': 'd29a3350-d45d-4b82-a537-470c92e6ec98',
#     'name': '77499003',
#     'displayName': '77499003',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-23 03:23:22',
#     'modificationTime': '2019-06-23 03:23:22',
#     'createdBy': 'LE_SSO'},
#    {'id': 'c0734f1f-be6c-4a29-a979-2cf092d3d96f',
#     'name': '2022139',
#     'displayName': '2022139',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 22:56:09',
#     'modificationTime': '2019-06-19 22:56:09',
#     'createdBy': 'LE_SSO'},
#    {'id': '38fc99d0-9c94-452e-bbdd-bb0a4f62dbe0',
#     'name': '18391146',
#     'displayName': '18391146',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 14:21:09',
#     'modificationTime': '2019-06-19 14:21:09',
#     'createdBy': 'LE_SSO'},
#    {'id': '15133173-d84f-499d-af69-195afcf73841',
#     'name': '35165181',
#     'displayName': '35165181',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 17:23:35',
#     'modificationTime': '2019-06-19 17:23:35',
#     'createdBy': 'LE_SSO'},
#    {'id': '73a00cdc-16ef-4c42-a4ce-eec7121c87dd',
#     'name': '43346860',
#     'displayName': '43346860',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 14:28:46',
#     'modificationTime': '2019-06-19 14:28:46',
#     'createdBy': 'LE_SSO'},
#    {'id': 'f7dc7432-6a48-498e-be52-0ee489916fb7',
#     'name': 'infosys',
#     'displayName': 'InfoSys',
#     'addressLine': '475 10th Avenue 5th Floor',
#     'addressLine2': '',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'US',
#     'postalCode': '',
#     'type': 'ADMIN',
#     'primaryContactName': 'Oren Katz',
#     'primaryContactEmail': 'orenk@liveperson.com',
#     'primaryContactPhone': '17704316331',
#     'billingContactName': 'Oren Katz',
#     'billingContactEmail': 'orenk@liveperson.com',
#     'billingContactPhone': '17704316331',
#     'creationTime': '2019-06-11 14:08:53',
#     'modificationTime': '2019-06-11 14:08:53'},
#    {'id': '64dea825-d959-451e-be92-666766ebf7f7',
#     'name': '78895802',
#     'displayName': '78895802',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-23 19:25:34',
#     'modificationTime': '2019-06-23 19:25:34',
#     'createdBy': 'LE_SSO'},
#    {'id': 'd2084ccd-986b-4c42-a871-f65245365bbf',
#     'name': 'botcentral',
#     'displayName': 'botcentral',
#     'addressLine': '465 Fairchild dr',
#     'city': 'Mountain View',
#     'state': 'CA',
#     'country': 'US',
#     'website': 'www.liveperson.com',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ravikiran Chittari',
#     'primaryContactEmail': 'rchittari@liveperson.com',
#     'primaryContactPhone': '4083002525',
#     'billingContactName': 'Ravikiran Chittari',
#     'billingContactEmail': 'rchittari@liveperson.com',
#     'billingContactPhone': '4083002525',
#     'modificationTime': '2018-06-01 23:17:06'},
#    {'id': 'd8604626-3d84-4bb4-a2f7-87c81db1671f',
#     'name': '16545413',
#     'displayName': '16545413',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 21:52:28',
#     'modificationTime': '2019-06-19 21:52:28',
#     'createdBy': 'LE_SSO'},
#    {'id': '06a01cd0-a5fa-4efc-be83-d3d2b881a84d',
#     'name': '8894374',
#     'displayName': '8894374',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-25 00:15:23',
#     'modificationTime': '2019-06-25 00:15:23',
#     'createdBy': 'LE_SSO'},
#    {'id': '3a4ed80a-5aae-4961-8424-177aa05e0a5a',
#     'name': '22391918',
#     'displayName': '22391918',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 21:08:19',
#     'modificationTime': '2019-06-19 21:08:19',
#     'createdBy': 'LE_SSO'},
#    {'id': 'f48e0e78-b50a-4b3a-b5ba-6cc762f5e574',
#     'name': '22315095',
#     'displayName': '22315095',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-25 17:07:26',
#     'modificationTime': '2019-06-25 17:07:26',
#     'createdBy': 'LE_SSO'},
#    {'id': '808295fc-dc6b-43ae-a80d-614148425fa3',
#     'name': '38856539',
#     'displayName': '38856539',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-20 01:24:41',
#     'modificationTime': '2019-06-20 01:24:41',
#     'createdBy': 'LE_SSO'},
#    {'id': 'd6d32542-a1e4-4163-b9d6-363af7b19312',
#     'name': 'qa',
#     'displayName': 'QA',
#     'addressLine': '485 N Whisman Road',
#     'city': 'Mountain View',
#     'state': 'CA',
#     'country': 'US',
#     'postalCode': '94043',
#     'type': 'ADMIN',
#     'primaryContactName': 'Ravikiran Chittari',
#     'primaryContactEmail': 'ravi@botcentral.ai',
#     'primaryContactPhone': '555-555-5555',
#     'billingContactName': 'Jon Altschuler',
#     'billingContactEmail': 'jon@botcentral.ai',
#     'billingContactPhone': '555-555-5555',
#     'creationTime': '2019-05-17 17:50:08',
#     'modificationTime': '2019-05-17 17:50:08'},
#    {'id': 'f387e0f6-a48d-44c6-a84f-e02fd63a357c',
#     'name': '51254786',
#     'displayName': '51254786',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-20 04:07:17',
#     'modificationTime': '2019-06-20 04:07:17',
#     'createdBy': 'LE_SSO'},
#    {'id': '122bdf3b-ca02-4dd7-ba42-3435ef8896ea',
#     'name': '52098983',
#     'displayName': '52098983',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-19 18:34:55',
#     'modificationTime': '2019-06-19 18:34:55',
#     'createdBy': 'LE_SSO'},
#    {'id': 'f4a2bc0d-f3cf-4cff-992b-ec7dbc401fd7',
#     'name': '87947068',
#     'displayName': '87947068',
#     'type': 'LIVE_ENGAGE',
#     'creationTime': '2019-06-20 00:14:24',
#     'modificationTime': '2019-06-20 00:14:24',
#     'createdBy': 'LE_SSO'}]}}

# %%
import requests

def getAllBotsInOrg(id):
    url = "https://sy.bc-platform.liveperson.net/bot-platform-manager-0.1/chatbots"

    payload = ""
    headers = {
        'Authorization': AUTH_KEY,
        'OrganizationId': id,
        'Content-Type': "application/json",
        'cache-control': "no-cache"
        }

    response = requests.request("GET", url, data=payload, headers=headers)

    return response.json()

# %%
all_nodes = getNodeStatus()
orgs = getOrgs()

# %%
bots = getAllBotsInOrg('eaee7e0e-0f01-4e91-9e48-68fd1b07e378')
bots['successResult']['chatBotSummaryList']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-c91ab0ea6d6a> in <module>
#       1 bots = getAllBotsInOrg('eaee7e0e-0f01-4e91-9e48-68fd1b07e378')
# ----> 2 bots['successResult']['chatBotSummaryList']
#
# KeyError: 'chatBotSummaryList'

# %%
import copy
all_orgs = orgs['successResult']['organziations']

bots_with_org = []
for i, org in enumerate(all_orgs):
    try:
        print(i, org)
        bots = getAllBotsInOrg(org['id'])
        for bot in bots['successResult']['chatBotSummaryList']:
            bot['orgName'] = org.get('name', None)
            bot['orgId'] = org.get('id', None)
            bot['orgCountry'] = org.get('country', None)
            bots_with_org.append(copy.deepcopy(bot))
    except:
        continue
# Out:
# 0 {'id': '1ee06326-727c-4b92-b2b2-31167a204e43', 'name': '19465488', 'displayName': '19465488', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 20:40:09', 'modificationTime': '2019-06-19 20:40:09', 'createdBy': 'LE_SSO'}
# 1 {'id': '102fb7c9-4bed-45a4-b595-258d592f6e43', 'name': '63627617', 'displayName': '63627617', 'addressLine': '485 N Whisman Rd', 'addressLine2': 'Office 100', 'city': 'Mountain View', 'state': 'CA', 'country': 'US', 'postalCode': '94043', 'type': 'ADMIN', 'primaryContactName': 'Sergey Kalashian', 'primaryContactEmail': 'sergeyk@liveperson.com', 'primaryContactPhone': '1234', 'billingContactName': 'Sergey Kalashian', 'billingContactEmail': 'sergeyk@liveperson.com', 'billingContactPhone': '1234', 'creationTime': '2019-06-05 13:34:02', 'modificationTime': '2019-06-05 13:34:02'}
# 2 {'id': '86b40dc5-d6cd-47ac-bd1a-e659cf91ef8a', 'name': '73948358', 'displayName': '73948358', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 17:21:44', 'modificationTime': '2019-06-19 17:21:44', 'createdBy': 'LE_SSO'}
# 3 {'id': '02771838-1adc-4466-b4c0-aa38542ecb23', 'name': '23197511', 'displayName': '23197511', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 14:23:25', 'modificationTime': '2019-06-19 14:23:25', 'createdBy': 'LE_SSO'}
# 4 {'id': 'faa0f639-5886-41db-8a0f-d95d14bb2ee4', 'name': '33350555', 'displayName': '33350555', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 18:47:31', 'modificationTime': '2019-06-19 18:47:31', 'createdBy': 'LE_SSO'}
# 5 {'id': 'c761f097-2c21-4742-ba09-04d1e2042ea3', 'name': '75330252', 'displayName': '75330252', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 21:42:53', 'modificationTime': '2019-06-19 21:42:53', 'createdBy': 'LE_SSO'}
# 6 {'id': '4239987c-af76-4314-a744-0d45167b68f2', 'name': '25644629', 'displayName': '25644629', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-25 13:45:39', 'modificationTime': '2019-06-25 13:45:39', 'createdBy': 'LE_SSO'}
# 7 {'id': '829c6c20-ae01-4b91-b1ed-58358f90f6b4', 'name': '63455983', 'displayName': '63455983', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 14:21:57', 'modificationTime': '2019-06-19 14:21:57', 'createdBy': 'LE_SSO'}
# 8 {'id': '103639cf-03fe-4650-a85f-0982b34f27ad', 'name': '43249447', 'displayName': '43249447', 'addressLine': '485 N Whisman Rd', 'addressLine2': 'Office 100', 'city': 'Mountain View', 'state': 'CA', 'country': 'US', 'postalCode': '94043', 'type': 'ADMIN', 'primaryContactName': 'Sergey Kalashian', 'primaryContactEmail': 'sergeyk@liveperson.com', 'primaryContactPhone': '1234', 'billingContactName': 'Sergey Kalashian', 'billingContactEmail': 'sergeyk@liveperson.com', 'billingContactPhone': '1234', 'creationTime': '2019-06-05 13:35:27', 'modificationTime': '2019-06-05 13:35:27'}
# 9 {'id': '54378c38-74dd-4786-a2a9-c053f3fbe38e', 'name': '27984200', 'displayName': '27984200', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 13:38:59', 'modificationTime': '2019-06-19 13:38:59', 'createdBy': 'LE_SSO'}
# 10 {'id': '7ccee28d-8634-413b-9ecb-d7b77c88f1ac', 'name': '5445139', 'displayName': '5445139', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-20 09:17:16', 'modificationTime': '2019-06-20 09:17:16', 'createdBy': 'LE_SSO'}
# 11 {'id': '37fbc083-cb3d-42ba-a901-217f6565ceb2', 'name': '82620305', 'displayName': '82620305', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 21:43:25', 'modificationTime': '2019-06-19 21:43:25', 'createdBy': 'LE_SSO'}
# 12 {'id': 'd29a3350-d45d-4b82-a537-470c92e6ec98', 'name': '77499003', 'displayName': '77499003', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-23 03:23:22', 'modificationTime': '2019-06-23 03:23:22', 'createdBy': 'LE_SSO'}
# 13 {'id': 'c0734f1f-be6c-4a29-a979-2cf092d3d96f', 'name': '2022139', 'displayName': '2022139', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 22:56:09', 'modificationTime': '2019-06-19 22:56:09', 'createdBy': 'LE_SSO'}
# 14 {'id': '38fc99d0-9c94-452e-bbdd-bb0a4f62dbe0', 'name': '18391146', 'displayName': '18391146', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 14:21:09', 'modificationTime': '2019-06-19 14:21:09', 'createdBy': 'LE_SSO'}
# 15 {'id': '15133173-d84f-499d-af69-195afcf73841', 'name': '35165181', 'displayName': '35165181', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 17:23:35', 'modificationTime': '2019-06-19 17:23:35', 'createdBy': 'LE_SSO'}
# 16 {'id': '73a00cdc-16ef-4c42-a4ce-eec7121c87dd', 'name': '43346860', 'displayName': '43346860', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 14:28:46', 'modificationTime': '2019-06-19 14:28:46', 'createdBy': 'LE_SSO'}
# 17 {'id': 'f7dc7432-6a48-498e-be52-0ee489916fb7', 'name': 'infosys', 'displayName': 'InfoSys', 'addressLine': '475 10th Avenue 5th Floor', 'addressLine2': '', 'city': 'New York', 'state': 'NY', 'country': 'US', 'postalCode': '', 'type': 'ADMIN', 'primaryContactName': 'Oren Katz', 'primaryContactEmail': 'orenk@liveperson.com', 'primaryContactPhone': '17704316331', 'billingContactName': 'Oren Katz', 'billingContactEmail': 'orenk@liveperson.com', 'billingContactPhone': '17704316331', 'creationTime': '2019-06-11 14:08:53', 'modificationTime': '2019-06-11 14:08:53'}
# 18 {'id': '64dea825-d959-451e-be92-666766ebf7f7', 'name': '78895802', 'displayName': '78895802', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-23 19:25:34', 'modificationTime': '2019-06-23 19:25:34', 'createdBy': 'LE_SSO'}
# 19 {'id': 'd2084ccd-986b-4c42-a871-f65245365bbf', 'name': 'botcentral', 'displayName': 'botcentral', 'addressLine': '465 Fairchild dr', 'city': 'Mountain View', 'state': 'CA', 'country': 'US', 'website': 'www.liveperson.com', 'type': 'ADMIN', 'primaryContactName': 'Ravikiran Chittari', 'primaryContactEmail': 'rchittari@liveperson.com', 'primaryContactPhone': '4083002525', 'billingContactName': 'Ravikiran Chittari', 'billingContactEmail': 'rchittari@liveperson.com', 'billingContactPhone': '4083002525', 'modificationTime': '2018-06-01 23:17:06'}
# 20 {'id': 'd8604626-3d84-4bb4-a2f7-87c81db1671f', 'name': '16545413', 'displayName': '16545413', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 21:52:28', 'modificationTime': '2019-06-19 21:52:28', 'createdBy': 'LE_SSO'}
# 21 {'id': '06a01cd0-a5fa-4efc-be83-d3d2b881a84d', 'name': '8894374', 'displayName': '8894374', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-25 00:15:23', 'modificationTime': '2019-06-25 00:15:23', 'createdBy': 'LE_SSO'}
# 22 {'id': '3a4ed80a-5aae-4961-8424-177aa05e0a5a', 'name': '22391918', 'displayName': '22391918', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 21:08:19', 'modificationTime': '2019-06-19 21:08:19', 'createdBy': 'LE_SSO'}
# 23 {'id': 'f48e0e78-b50a-4b3a-b5ba-6cc762f5e574', 'name': '22315095', 'displayName': '22315095', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-25 17:07:26', 'modificationTime': '2019-06-25 17:07:26', 'createdBy': 'LE_SSO'}
# 24 {'id': '808295fc-dc6b-43ae-a80d-614148425fa3', 'name': '38856539', 'displayName': '38856539', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-20 01:24:41', 'modificationTime': '2019-06-20 01:24:41', 'createdBy': 'LE_SSO'}
# 25 {'id': 'd6d32542-a1e4-4163-b9d6-363af7b19312', 'name': 'qa', 'displayName': 'QA', 'addressLine': '485 N Whisman Road', 'city': 'Mountain View', 'state': 'CA', 'country': 'US', 'postalCode': '94043', 'type': 'ADMIN', 'primaryContactName': 'Ravikiran Chittari', 'primaryContactEmail': 'ravi@botcentral.ai', 'primaryContactPhone': '555-555-5555', 'billingContactName': 'Jon Altschuler', 'billingContactEmail': 'jon@botcentral.ai', 'billingContactPhone': '555-555-5555', 'creationTime': '2019-05-17 17:50:08', 'modificationTime': '2019-05-17 17:50:08'}
# 26 {'id': 'f387e0f6-a48d-44c6-a84f-e02fd63a357c', 'name': '51254786', 'displayName': '51254786', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-20 04:07:17', 'modificationTime': '2019-06-20 04:07:17', 'createdBy': 'LE_SSO'}
# 27 {'id': '122bdf3b-ca02-4dd7-ba42-3435ef8896ea', 'name': '52098983', 'displayName': '52098983', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-19 18:34:55', 'modificationTime': '2019-06-19 18:34:55', 'createdBy': 'LE_SSO'}
# 28 {'id': 'f4a2bc0d-f3cf-4cff-992b-ec7dbc401fd7', 'name': '87947068', 'displayName': '87947068', 'type': 'LIVE_ENGAGE', 'creationTime': '2019-06-20 00:14:24', 'modificationTime': '2019-06-20 00:14:24', 'createdBy': 'LE_SSO'}

# %%
len(all_orgs)
# Out:
# 29

# %%
botIdOrgDictionary = {}
for item in bots_with_org:
    try:
        botIdOrgDictionary[item['chatBot']['id']] = item
    except Exception as e:
        print(e, item)
        continue

# %%
import pandas as pd

# %%
botIdDictionary = {}
for item in result['statusList']:
    botId = item['botId']
    if botId in botIdDictionary.keys():
        botIdDictionary[botId].append(item)
    else:
        botIdDictionary[botId] = [item]

# %%
botIdOrgDictionary['d7b1bedab9a31dcba60b2591302c38fb1ce68d2b'], botIdDictionary['d7b1bedab9a31dcba60b2591302c38fb1ce68d2b']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-399fed6dc51f> in <module>
# ----> 1 botIdOrgDictionary['d7b1bedab9a31dcba60b2591302c38fb1ce68d2b'], botIdDictionary['d7b1bedab9a31dcba60b2591302c38fb1ce68d2b']
#
# KeyError: 'd7b1bedab9a31dcba60b2591302c38fb1ce68d2b'

# %%
len(botIdDictionary.items()), len(botIdOrgDictionary.items())
# Out:
# (6, 16)

# %%
import json

statusInfoArr = []
for idx, (k, statusInfoList) in enumerate(botIdDictionary.items()):
    try:
        for statusInfo in statusInfoList:
            bot = botIdOrgDictionary.get(k, {})
            lpSocketStatus = json.loads(statusInfo['lpSocketStatus'])['status'] if statusInfo['lpSocketStatus'] and statusInfo['lpSocketStatus'] != 'unknown' else 'unknown'
            bcSocketStatus = json.loads(statusInfo['bcSocketStatus'])['status'] if statusInfo['bcSocketStatus'] and statusInfo['lpSocketStatus'] != 'unknown' else 'unknown'
            statusKeys = statusInfo.keys()
            status = [statusInfo.get('botId', None),
                      statusInfo.get('botName', None),
                      statusInfo.get('environment', None),
                      statusInfo.get('serverName', None),
                      statusInfo.get('lpAccountId', None),
                      statusInfo.get('lpAccountUser', None),
                      statusInfo.get('type', None),
                      bot.get('orgId', None),
                      bot.get('orgName', None),
                      bot.get('orgCountry', None),
                      bot.get('chatBot', {}).get('version', None),
                      bcSocketStatus,
                      statusInfo.get('nodeStatus', None),
                      lpSocketStatus]
            statusInfoArr.append(status)
    except Exception as e:
#         print(e)
        print(idx, k, bot['chatBot']['name'])
        continue

# %%
botIdDictionary['1929dd0634515575b03cba583d5e75d447d3a461'], botIdOrgDictionary['1929dd0634515575b03cba583d5e75d447d3a461']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-8205bb6ee2ea> in <module>
# ----> 1 botIdDictionary['1929dd0634515575b03cba583d5e75d447d3a461'], botIdOrgDictionary['1929dd0634515575b03cba583d5e75d447d3a461']
#
# KeyError: '1929dd0634515575b03cba583d5e75d447d3a461'

# %%
df = pd.DataFrame(statusInfoArr, columns = ['botId', 'botName',
                                            'environment','serverName','lpAccountId','lpAccountUser',
                                            'type','orgId','orgName','orgCountry','version', 'bcSocketStatus',
                                           'nodeStatus','lpSocketStatus'])

# %%
len(df)
# Out:
# 6

# %%
df.to_csv('~/notebooks/bot_results_lp_ap.csv', index=None)

# %%
# !open ./
